# %% [markdown]
# ## Day 0 vs Day 30
# The data used in this notebook is lymphocyte data for two patient's B cells and T cells from 2 time points. We use this data to show the proteome variation between collection times.
#
# Here, we note presence/absense changes and quantify fold changes using a T test.

# %% [markdown]
# ### Access data
# First, we import our data package. This brings the functions defined there into scope so we can use them in this script. Then we can create a proteomic dataset object and store it as <code>prot</code>. You can select versions and subjects with <code>load_dataset</code>.
#
# Calling <code>head</code> shows the first several lines of the dataframe, which provides an idea of the type of data present and the structure of the dataframe.

# %%
import longitudinalCLL
prot = longitudinalCLL.get_proteomic()
prot2 = longitudinalCLL.get_proteomic()

prot.load_dataset(version='July_noMBR_FP', subjects = [1])
prot2.load_dataset(version='July_noMBR_FP', subjects = [2])

prot.data_raw.head()
# Out:
#             Subject1_B_cells_062920_C_10  Subject1_B_cells_062920_C_11  \
# Protein ID
# A0A0B4J2D5                     3203277.5                     4697996.0
# A0AVT1                         1917388.2                     3033529.2
# A0FGR8                               0.0                           0.0
# A6NHR9                         2650513.5                           0.0
# A8K2U0                               0.0                           0.0
#
#             Subject1_B_cells_062920_C_12  Subject1_B_cells_062920_C_13  \
# Protein ID
# A0A0B4J2D5                     7346776.5                     8472867.0
# A0AVT1                         3773018.8                     1865758.6
# A0FGR8                               0.0                           0.0
# A6NHR9                         3788095.8                           0.0
# A8K2U0                               0.0                     1149867.8
#
#             Subject1_B_cells_062920_C_9  Subject1_B_cells_072920_C_4  \
# Protein ID
# A0A0B4J2D5                    4280919.5                          0.0
# A0AVT1                        5191332.5                    3332031.5
# A0FGR8                              0.0                          0.0
# A6NHR9                              0.0                    1845555.5
# A8K2U0                              0.0                          0.0
#
#             Subject1_B_cells_072920_C_5  Subject1_B_cells_072920_C_6  \
# Protein ID
# A0A0B4J2D5                   4787781.50                    2153860.2
# A0AVT1                       2464089.00                    2290868.2
# A0FGR8                             0.00                          0.0
# A6NHR9                        933499.44                    1958162.5
# A8K2U0                             0.00                          0.0
#
#             Subject1_B_cells_072920_C_8  Subject1_B_cells_072920_C_9  \
# Protein ID
# A0A0B4J2D5                    5444238.5                   5514300.50
# A0AVT1                        2486001.2                   2596365.20
# A0FGR8                              0.0                         0.00
# A6NHR9                        1604476.4                    418360.38
# A8K2U0                        2272656.2                         0.00
#
#             Subject1_T_cells_062920_D_10  Subject1_T_cells_062920_D_11  \
# Protein ID
# A0A0B4J2D5                     1452451.2                           0.0
# A0AVT1                               0.0                     2869977.5
# A0FGR8                               0.0                           0.0
# A6NHR9                          907359.0                           0.0
# A8K2U0                               0.0                           0.0
#
#             Subject1_T_cells_062920_D_12  Subject1_T_cells_062920_D_13  \
# Protein ID
# A0A0B4J2D5                     219754.92                          0.00
# A0AVT1                              0.00                          0.00
# A0FGR8                              0.00                          0.00
# A6NHR9                              0.00                     159779.72
# A8K2U0                              0.00                          0.00
#
#             Subject1_T_cells_062920_D_9  Subject1_T_cells_072920_D_2  \
# Protein ID
# A0A0B4J2D5                     679607.9                   2275364.50
# A0AVT1                        1394525.6                   2804357.20
# A0FGR8                              0.0                    756851.44
# A6NHR9                              0.0                         0.00
# A8K2U0                              0.0                         0.00
#
#             Subject1_T_cells_072920_D_4  Subject1_T_cells_072920_D_5  \
# Protein ID
# A0A0B4J2D5                    3411472.8                          0.0
# A0AVT1                        1830829.1                    1185091.1
# A0FGR8                              0.0                          0.0
# A6NHR9                              0.0                          0.0
# A8K2U0                              0.0                          0.0
#
#             Subject1_T_cells_072920_D_6  Subject1_T_cells_072920_D_7
# Protein ID
# A0A0B4J2D5                    1205392.9                    1030751.8
# A0AVT1                        1250515.2                    1041313.3
# A0FGR8                              0.0                    1197022.1
# A6NHR9                        1074709.6                          0.0
# A8K2U0                              0.0                          0.0

# %% [markdown]
# Our next steps will require separating the runs by cell type, to compare B cells to T cells. As you see above, the pattern for naming the columns is Subject, B or T cell type, date, and the replicate number. Here we define the list of cell types that the functions should look for based on the naming pattern.
#
# Note that the <code>prot</code> data is only from subject 1, which could also be specified <code>cell_types=['Subject1_B_cells_062920', 'Subject1_B_cells_072920']</code>
# This could also be simplified as <code>cell_types=['B_cells_07', 'B_cells_06']</code> as the only requirement is that this string is in all replicates that you want to include and no other samples.

# %%
cell_types=['B_cells_072920', 'B_cells_062920']

# %% [markdown]
# We can check which proteins are only identified in one cell type. We'll set these aside for now, in the <code>data_in_one_type</code> dataframe. For our analysis, present in more than half, or at least 3 out of 5 replicates, is considered clear although it is interesting to note those proteins identified in all replicates of one type.

# %%
present_only_in = prot.check_presence_absence(min_reps=3, cell_types=cell_types, null_value=0).dropna()

print("Proteins identified only in:")
print(present_only_in.value_counts())
data_in_one_type =prot.data_frame.loc[present_only_in.index]
data_in_one_type['Type'] = present_only_in
# Out:
# Proteins identified only in:
# B_cells_072920    78
# B_cells_062920    12
# dtype: int64

# %%
present_only_in_2 = prot2.check_presence_absence(min_reps=3, cell_types=cell_types, null_value=0).dropna()

print("Proteins identified only in:")
print(present_only_in.value_counts())
data_in_one_type_2 =prot2.data_frame.loc[present_only_in.index]
data_in_one_type_2['Type'] = present_only_in_2
# Out:
# Proteins identified only in:
# B_cells_072920    78
# B_cells_062920    12
# dtype: int64

# %% [markdown]
# The <code>min_reps</code> is the minimum number of replicates required to list a protein as present in one type. This can be changed, i.e., <code>min_reps=5</code> to determine the proteins identified in all 5 replicates of a single type. Be careful not set it to a number greater than the replicates run or no proteins will be returned.

# %%
present_5of5_only_in = prot.check_presence_absence(min_reps=5, cell_types=cell_types, null_value=0).dropna()

# %%
present_5of5_only_in_2 = prot2.check_presence_absence(min_reps=5, cell_types=cell_types, null_value=0).dropna()

# %%
print("Proteins identified in 5/5 replicates only in:")
print(present_5of5_only_in.value_counts())
data_in_5of5_one_type =prot.data_frame.loc[present_5of5_only_in.index]
data_in_5of5_one_type['Type'] = present_5of5_only_in
# Out:
# Proteins identified in 5/5 replicates only in:
# B_cells_072920    11
# B_cells_062920     4
# dtype: int64

# %%
print("Proteins identified in 5/5 replicates only in:")
print(present_5of5_only_in_2.value_counts())
data_in_5of5_one_type_2 =prot2.data_frame.loc[present_5of5_only_in.index]
data_in_5of5_one_type_2['Type'] = present_5of5_only_in_2
# Out:
# Proteins identified in 5/5 replicates only in:
# B_cells_072920    90
# B_cells_062920     5
# dtype: int64

# %% [markdown]
# ### Filter data
# Next, we select the proteins that are measured in at least three samples from each group, allowing the calculations to proceed without imputed zero-handling.

# %%
indecies = prot.check_n_of_each_type(cell_types=cell_types, null_value=0)
prot.data_frame = prot.data_frame[indecies]

# %%
indecies_2 = prot2.check_n_of_each_type(cell_types=cell_types, null_value=0)
prot2.data_frame = prot2.data_frame[indecies_2]

# %%
print ("Total groups identified:")
print(prot.data_raw.shape[0])

print ("Proteins identified in at least 3 of each cell type:\t")
print (prot.data_frame.shape[0])
# Out:
# Total groups identified:
# 2426
# Proteins identified in at least 3 of each cell type:
# 1122

# %%
print ("Total groups identified:")
print(prot2.data_raw.shape[0])

print ("Proteins identified in at least 3 of each cell type:\t")
print (prot2.data_frame.shape[0])
# Out:
# Total groups identified:
# 2426
# Proteins identified in at least 3 of each cell type:
# 1135

# %% [markdown]
# Before any analysis, we log normalize and median normalize across runs. We need to do this after filtering for consistently expressed proteins so those only identified in some rows do not throw off the normalization.

# %%
prot.normalize()

#prot.data_frame.head()
# Out:
#             Subject1_B_cells_062920_C_10  Subject1_B_cells_062920_C_11  \
# Protein ID
# A0A0B4J2D5                     -0.907284                     -0.614455
# A0AVT1                         -1.647690                     -1.245503
# A8MWD9                         -1.705659                     -0.897494
# O00148                          1.756529                      1.663173
# O00151                          0.363874                      0.358541
# ...                                  ...                           ...
# P62891                         -1.492198                     -1.406654
# Q16563                               NaN                     -1.274117
# Q6BDS2                          4.617630                      2.760630
# Q8NDC0                         -1.554426                     -2.347147
# Q9Y237                         -1.553604                           NaN
#
#             Subject1_B_cells_062920_C_12  Subject1_B_cells_062920_C_13  \
# Protein ID
# A0A0B4J2D5                      0.324358                      0.129667
# A0AVT1                         -0.637034                     -2.053420
# A8MWD9                         -1.544551                     -0.890077
# O00148                          1.728240                      1.342271
# O00151                          0.339119                      0.198522
# ...                                  ...                           ...
# P62891                         -1.376146                     -1.055795
# Q16563                         -0.733469                     -0.523787
# Q6BDS2                               NaN                           NaN
# Q8NDC0                         -0.550999                     -7.565106
# Q9Y237                               NaN                     -2.038530
#
#             Subject1_B_cells_062920_C_9  Subject1_B_cells_072920_C_4  \
# Protein ID
# A0A0B4J2D5                    -0.620956                          NaN
# A0AVT1                        -0.342772                    -0.837361
# A8MWD9                        -1.331158                          NaN
# O00148                         1.153263                     1.725132
# O00151                         0.203450                     0.979911
# ...                                 ...                          ...
# P62891                        -1.227822                          NaN
# Q16563                              NaN                          NaN
# Q6BDS2                         2.859740                     2.562322
# Q8NDC0                              NaN                    -0.833633
# Q9Y237                        -2.532553                    -2.635800
#
#             Subject1_B_cells_072920_C_5  Subject1_B_cells_072920_C_6  \
# Protein ID
# A0A0B4J2D5                    -0.311569                    -1.484273
# A0AVT1                        -1.269872                    -1.395303
# A8MWD9                        -0.411948                    -0.585962
# O00148                         1.529139                     1.568251
# O00151                         1.094552                     0.934537
# ...                                 ...                          ...
# P62891                        -0.456711                    -0.283975
# Q16563                        -1.479278                          NaN
# Q6BDS2                         3.907445                     2.983677
# Q8NDC0                        -1.163423                    -0.971098
# Q9Y237                              NaN                          NaN
#
#             Subject1_B_cells_072920_C_8  Subject1_B_cells_072920_C_9  \
# Protein ID
# A0A0B4J2D5                    -0.248072                    -0.127279
# A0AVT1                        -1.378975                    -1.213963
# A8MWD9                        -1.004273                    -0.964572
# O00148                         1.306042                     1.397598
# O00151                         0.569258                     0.845804
# ...                                 ...                          ...
# P62891                        -0.606453                    -0.430345
# Q16563                        -0.663565                    -1.861305
# Q6BDS2                         1.548954                     3.721366
# Q8NDC0                              NaN                    -1.057692
# Q9Y237                        -2.312178                    -2.264584
#
#             Subject1_T_cells_062920_D_10  Subject1_T_cells_062920_D_11  \
# Protein ID
# A0A0B4J2D5                     -2.251177                           NaN
# A0AVT1                               NaN                     -1.206813
# A8MWD9                               NaN                     -2.440606
# O00148                          1.304878                      1.166107
# O00151                               NaN                           NaN
# ...                                  ...                           ...
# P62891                         -0.791613                     -1.003668
# Q16563                               NaN                           NaN
# Q6BDS2                          4.738559                           NaN
# Q8NDC0                         -2.166828                     -2.776075
# Q9Y237                               NaN                     -3.311214
#
#             Subject1_T_cells_062920_D_12  Subject1_T_cells_062920_D_13  \
# Protein ID
# A0A0B4J2D5                     -4.932781                           NaN
# A0AVT1                               NaN                           NaN
# A8MWD9                               NaN                           NaN
# O00148                          1.406438                      1.304433
# O00151                         -3.448459                     -2.321541
# ...                                  ...                           ...
# P62891                         -0.173203                     -0.546825
# Q16563                               NaN                           NaN
# Q6BDS2                          4.612580                      4.037585
# Q8NDC0                        -11.163840                     -1.814741
# Q9Y237                               NaN                     -1.994957
#
#             Subject1_T_cells_062920_D_9  Subject1_T_cells_072920_D_2  \
# Protein ID
# A0A0B4J2D5                    -3.325712                    -1.427978
# A0AVT1                        -2.288712                    -1.126406
# A8MWD9                        -2.463485                    -0.448648
# O00148                         1.253088                     1.272149
# O00151                        -2.206959                    -0.557094
# ...                                 ...                          ...
# P62891                        -0.716860                          NaN
# Q16563                              NaN                          NaN
# Q6BDS2                         1.445404                     4.536025
# Q8NDC0                              NaN                    -1.233578
# Q9Y237                        -2.577067                          NaN
#
#             Subject1_T_cells_072920_D_4  Subject1_T_cells_072920_D_5  \
# Protein ID
# A0A0B4J2D5                    -0.862720                          NaN
# A0AVT1                        -1.760617                    -2.441295
# A8MWD9                        -1.677343                    -1.502907
# O00148                         1.186986                     1.227216
# O00151                        -1.260376                    -0.836514
# ...                                 ...                          ...
# P62891                        -0.203491                    -0.139948
# Q16563                              NaN                          NaN
# Q6BDS2                         3.901479                     1.143441
# Q8NDC0                        -2.325011                    -1.772960
# Q9Y237                              NaN                          NaN
#
#             Subject1_T_cells_072920_D_6  Subject1_T_cells_072920_D_7
# Protein ID
# A0A0B4J2D5                    -2.361136                    -2.695371
# A0AVT1                        -2.308117                    -2.680664
# A8MWD9                        -0.581798                          NaN
# O00148                         1.426776                     1.299393
# O00151                        -0.851017                    -0.579521
# ...                                 ...                          ...
# P62891                        -0.078113                    -0.708715
# Q16563                              NaN                          NaN
# Q6BDS2                         3.373929                     1.327737
# Q8NDC0                        -1.884140                    -1.633109
# Q9Y237                        -2.837646                          NaN
#
# [1122 rows x 20 columns]

# %%
prot2.normalize()

#prot2.data_frame.head()
# Out:
#             Subject2_B_cells_062920_E_11  Subject2_B_cells_062920_E_12  \
# Protein ID
# A0AVT1                         -1.527998                     -1.561431
# A6NHR9                         -0.764262                     -1.392726
# A8MWD9                         -3.559681                     -0.818561
# O00148                          1.835712                      1.819637
# O00151                          0.738653                      0.899835
# ...                                  ...                           ...
# Q8NDC0                               NaN                     -1.827981
# Q8N131                         -1.005917                     -0.545279
# Q9BXT2                         -0.632656                           NaN
# P05019                          0.339948                     -0.872194
# Q96BN6                         -1.022831                     -1.329842
#
#             Subject2_B_cells_062920_E_13  Subject2_B_cells_062920_E_16  \
# Protein ID
# A0AVT1                               NaN                     -1.452184
# A6NHR9                         -1.424490                     -1.279980
# A8MWD9                         -1.058135                           NaN
# O00148                          1.819495                      1.494635
# O00151                          0.915515                      0.991889
# ...                                  ...                           ...
# Q8NDC0                         -1.471047                           NaN
# Q8N131                         -1.292698                     -0.485246
# Q9BXT2                         -0.294329                           NaN
# P05019                         -0.547695                     -2.200311
# Q96BN6                         -0.542756                     -1.205125
#
#             Subject2_B_cells_062920_E_9  Subject2_B_cells_072920_E_1  \
# Protein ID
# A0AVT1                              NaN                          NaN
# A6NHR9                        -3.256592                    -1.516467
# A8MWD9                        -1.580312                    -1.548625
# O00148                         1.601738                     1.235148
# O00151                         0.038411                     0.513751
# ...                                 ...                          ...
# Q8NDC0                        -1.395796                    -1.687640
# Q8N131                        -0.680382                          NaN
# Q9BXT2                        -0.734254                          NaN
# P05019                              NaN                          NaN
# Q96BN6                        -1.941419                    -2.532014
#
#             Subject2_B_cells_072920_E_2  Subject2_B_cells_072920_E_4  \
# Protein ID
# A0AVT1                        -2.465358                    -0.893308
# A6NHR9                        -1.880991                    -1.481149
# A8MWD9                        -3.329704                    -1.670727
# O00148                         1.481961                     1.662952
# O00151                         1.104235                     0.965626
# ...                                 ...                          ...
# Q8NDC0                        -1.559382                    -0.848960
# Q8N131                        -1.533366                          NaN
# Q9BXT2                        -0.851003                    -0.089636
# P05019                        -0.976820                    -1.095712
# Q96BN6                              NaN                    -3.010277
#
#             Subject2_B_cells_072920_E_5  Subject2_B_cells_072920_E_7  ...  \
# Protein ID                                                            ...
# A0AVT1                        -1.835162                    -1.739436  ...
# A6NHR9                        -2.103805                    -1.643162  ...
# A8MWD9                              NaN                    -1.452554  ...
# O00148                         1.551758                     1.802674  ...
# O00151                         0.941106                     0.911324  ...
# ...                                 ...                          ...  ...
# Q8NDC0                        -1.832415                    -1.199482  ...
# Q8N131                        -1.486404                          NaN  ...
# Q9BXT2                        -1.053820                    -0.821363  ...
# P05019                        -0.732424                    -1.418961  ...
# Q96BN6                              NaN                          NaN  ...
#
#             Subject2_T_cells_062920_F_12  Subject2_T_cells_062920_F_13  \
# Protein ID
# A0AVT1                         -2.568679                     -3.361549
# A6NHR9                               NaN                           NaN
# A8MWD9                               NaN                           NaN
# O00148                          1.449518                      1.108128
# O00151                         -0.664246                     -1.929102
# ...                                  ...                           ...
# Q8NDC0                         -7.105583                     -2.333510
# Q8N131                               NaN                           NaN
# Q9BXT2                         -0.615356                           NaN
# P05019                         -2.189810                           NaN
# Q96BN6                         -0.204261                     -1.887887
#
#             Subject2_T_cells_062920_F_14  Subject2_T_cells_062920_F_9  \
# Protein ID
# A0AVT1                         -3.549985                          NaN
# A6NHR9                               NaN                          NaN
# A8MWD9                               NaN                    -1.261906
# O00148                          1.692753                     1.409062
# O00151                         -1.089269                    -1.483741
# ...                                  ...                          ...
# Q8NDC0                         -2.409326                          NaN
# Q8N131                               NaN                          NaN
# Q9BXT2                         -0.515508                          NaN
# P05019                         -0.772521                          NaN
# Q96BN6                         -2.025669                    -1.334874
#
#             Subject2_T_cells_072920_F_1  Subject2_T_cells_072920_F_3  \
# Protein ID
# A0AVT1                              NaN                          NaN
# A6NHR9                        -3.739504                          NaN
# A8MWD9                        -0.237535                    -1.282895
# O00148                         1.602150                     1.420930
# O00151                              NaN                    -1.315770
# ...                                 ...                          ...
# Q8NDC0                        -1.625236                    -1.873024
# Q8N131                              NaN                          NaN
# Q9BXT2                        -0.859714                    -0.907595
# P05019                              NaN                     0.523776
# Q96BN6                              NaN                    -2.421929
#
#             Subject2_T_cells_072920_F_4  Subject2_T_cells_072920_F_5  \
# Protein ID
# A0AVT1                              NaN                    -2.874807
# A6NHR9                              NaN                          NaN
# A8MWD9                        -1.637779                    -4.380759
# O00148                         1.340205                     1.346073
# O00151                        -1.222997                    -0.721689
# ...                                 ...                          ...
# Q8NDC0                        -1.909248                    -2.105315
# Q8N131                              NaN                          NaN
# Q9BXT2                        -0.974572                     0.082780
# P05019                        -0.647490                          NaN
# Q96BN6                        -3.285819                          NaN
#
#             Subject2_T_cells_072920_F_6  Subject2_T_cells_072920_F_8
# Protein ID
# A0AVT1                        -2.256912                          NaN
# A6NHR9                        -3.484590                    -2.680249
# A8MWD9                        -1.475489                          NaN
# O00148                         1.512034                     1.440320
# O00151                        -1.723913                    -1.149714
# ...                                 ...                          ...
# Q8NDC0                        -1.164081                    -1.201873
# Q8N131                              NaN                          NaN
# Q9BXT2                        -1.100058                     0.300496
# P05019                        -0.288050                    -0.451874
# Q96BN6                        -1.810075                    -1.707736
#
# [1135 rows x 23 columns]

# %% [markdown]
# ### Analysis
# Now we calulate p values using a ttest.

# %%
#Call ttest function
tstats = prot.ttest_wrapper(cell_types=cell_types)
tstats
# Out:
#             statistic    pvalue
# Protein ID
# A0A0B4J2D5        NaN       NaN
# A0AVT1      -0.102259  0.921068
# A8MWD9            NaN       NaN
# O00148      -0.168091  0.870684
# O00151       6.156584  0.000272
# ...               ...       ...
# P62891            NaN       NaN
# Q16563            NaN       NaN
# Q6BDS2            NaN       NaN
# Q8NDC0            NaN       NaN
# Q9Y237            NaN       NaN
#
# [1122 rows x 2 columns]

# %%
#Call ttest function
tstats_2 = prot2.ttest_wrapper(cell_types=cell_types)
tstats_2
# Out:
#             statistic    pvalue
# Protein ID
# A0AVT1            NaN       NaN
# A6NHR9      -0.195635  0.849242
# A8MWD9            NaN       NaN
# O00148      -1.546456  0.156397
# O00151       0.940302  0.371613
# ...               ...       ...
# Q8NDC0            NaN       NaN
# Q8N131            NaN       NaN
# Q9BXT2            NaN       NaN
# P05019            NaN       NaN
# Q96BN6            NaN       NaN
#
# [1135 rows x 2 columns]

# %% [markdown]
# Here we calculate fold change.

# %%
fc_comp = 'log2(30)-log2(0)'
tstats[fc_comp] = prot.get_fold_changes(cell_types=cell_types)

# %%
tstats
# Out:
#             statistic    pvalue  log2(30)-log2(0)
# Protein ID
# A0A0B4J2D5        NaN       NaN               NaN
# A0AVT1      -0.102259  0.921068         -0.033811
# A8MWD9            NaN       NaN               NaN
# O00148      -0.168091  0.870684         -0.023463
# O00151       6.156584  0.000272          0.592112
# ...               ...       ...               ...
# P62891            NaN       NaN               NaN
# Q16563            NaN       NaN               NaN
# Q6BDS2            NaN       NaN               NaN
# Q8NDC0            NaN       NaN               NaN
# Q9Y237            NaN       NaN               NaN
#
# [1122 rows x 3 columns]

# %%
fc_comp_2 = 'log2(30)-log2(0)'
tstats_2[fc_comp_2] = prot2.get_fold_changes(cell_types=cell_types)

# %%
tstats_2
# Out:
#             statistic    pvalue  log2(30)-log2(0)
# Protein ID
# A0AVT1            NaN       NaN               NaN
# A6NHR9      -0.195635  0.849242         -0.078082
# A8MWD9            NaN       NaN               NaN
# O00148      -1.546456  0.156397         -0.164685
# O00151       0.940302  0.371613          0.170345
# ...               ...       ...               ...
# Q8NDC0            NaN       NaN               NaN
# Q8N131            NaN       NaN               NaN
# Q9BXT2            NaN       NaN               NaN
# P05019            NaN       NaN               NaN
# Q96BN6            NaN       NaN               NaN
#
# [1135 rows x 3 columns]

# %%
import matplotlib.pyplot as plt
from matplotlib_venn import venn2
from matplotlib_venn import venn3
venn2(subsets = (set(tstats.index), set(tstats_2.index)), set_labels = ('Mayer', 'Johnston'))
#plt.savefig('data/diff_overlap.png')
plt.show()

# %% [markdown]
# Fold change and p values allow us to create a volcano plot.

# %%
#graph volcano
import matplotlib.pyplot as plt
import seaborn as sns
from numpy import log10
tstats['-log p'] = -log10(tstats['pvalue'])

figure = sns.scatterplot(x=fc_comp, y='-log p',data=tstats)
figure.set_title("B cells Time Dependent Change")
#plt.axvline(1, color ='orange')
#plt.axvline(-1, color ='orange')
plt.axhline(-log10(.05), color ='orange')
plt.show()

# %%
#graph volcano
tstats_2['-log p'] = -log10(tstats_2['pvalue'])

figure = sns.scatterplot(x=fc_comp_2, y='-log p',data=tstats_2)
figure.set_title("B cells Time Dependent Change")
#plt.axvline(1, color ='orange')
#plt.axvline(-1, color ='orange')
plt.axhline(-log10(.05), color ='orange')
plt.show()

# %% [markdown]
# Next we will identify the altered proteins.

# %%
altered = prot.is_altered(tstats, pvalue=.05, change_factor=False,
                          change_col=fc_comp, cell_types=cell_types)

# %%
altered_2 = prot2.is_altered(tstats_2, pvalue=.05, change_factor=False,
                          change_col=fc_comp_2, cell_types=cell_types)

# %%
tstats.loc[altered.index]
# Out:
#             statistic    pvalue  log2(30)-log2(0)    -log p
# Protein ID
# O00151       6.156584  0.000272          0.592112  3.565388
# O00483       2.821230  0.022451          0.463044  1.648758
# O14745       3.443456  0.008779          2.421507  2.056555
# O14773       5.752113  0.000428          0.643337  3.368598
# O14979      -4.488614  0.002032         -0.741820  2.691975
# ...               ...       ...               ...       ...
# Q96C86       2.575954  0.032822          0.393685  1.483832
# Q99832       3.066962  0.015419          0.353774  1.811949
# Q9UII2      -6.801759  0.000138         -1.155283  3.861457
# Q9Y2S6      -3.389959  0.009501         -0.452812  2.022252
# Q96JE7      -3.454878  0.008633         -0.578946  2.063858
#
# [168 rows x 4 columns]

# %%
tstats_2.loc[altered_2.index]
# Out:
#             statistic    pvalue  log2(30)-log2(0)    -log p
# Protein ID
# O00483       6.594799  0.000100          0.786119  4.000558
# O14602      -2.871585  0.018429         -0.807087  1.734497
# O14745       3.320670  0.008931          0.608084  2.049111
# O15144       2.411379  0.039160          0.411781  1.407153
# O15145       3.221717  0.010461          0.450541  1.980445
# ...               ...       ...               ...       ...
# Q9ULV4      -3.145611  0.011821         -0.803729  1.927355
# Q9Y3U8       5.118892  0.000629          1.104601  3.201407
# Q9Y5B9       2.495851  0.034093          0.490842  1.467333
# Q8IYD1       2.445254  0.037044          0.655153  1.431282
# Q96Q89      -3.066015  0.013440         -3.099123  1.871591
#
# [340 rows x 4 columns]

# %% [markdown]
# These are significantly altered (p<0.01) without restricting by the magnitude of change:

# %%
altered.value_counts()
# Out:
# B_cells_072920    118
# B_cells_062920     50
# dtype: int64

# %%
altered_2.value_counts()
# Out:
# B_cells_072920    256
# B_cells_062920     84
# dtype: int64

# %%
print("Here are counts for other p and change cutoffs:")
print("P<0.05, >150% of the other type")
print(prot.is_altered(tstats, pvalue=.05,change_factor=1.5,change_col=fc_comp, cell_types=cell_types).value_counts()) #50% increase from either
print("\nP<0.05, >200% of the other type")
print(prot.is_altered(tstats, pvalue=.05,change_factor=2,change_col=fc_comp, cell_types=cell_types).value_counts()) #Double
print("\nP<0.05, >500% of the other type")
print(prot.is_altered(tstats, pvalue=.05,change_factor=5,change_col=fc_comp, cell_types=cell_types).value_counts()) #5 times larger

print("\nP<0.01, >150% of the other type")
print(prot.is_altered(tstats, pvalue=.01,change_factor=1.5,change_col=fc_comp, cell_types=cell_types).value_counts()) #50% increase from either
print("\nP<0.01, >200% of the other type")
print(prot.is_altered(tstats, pvalue=.01,change_factor=2,change_col=fc_comp, cell_types=cell_types).value_counts()) #Double
print("\nP<0.01, >500% of the other type")
print(prot.is_altered(tstats, pvalue=.01,change_factor=5,change_col=fc_comp, cell_types=cell_types).value_counts()) #5 times larger
# Out:
# Here are counts for other p and change cutoffs:
# P<0.05, >150% of the other type
# B_cells_072920    59
# B_cells_062920    23
# dtype: int64
#
# P<0.05, >200% of the other type
# B_cells_072920    20
# B_cells_062920     5
# dtype: int64
#
# P<0.05, >500% of the other type
# B_cells_072920    1
# dtype: int64
#
# P<0.01, >150% of the other type
# B_cells_072920    27
# B_cells_062920    11
# dtype: int64
#
# P<0.01, >200% of the other type
# B_cells_072920    10
# B_cells_062920     4
# dtype: int64
#
# P<0.01, >500% of the other type
# B_cells_072920    1
# dtype: int64

# %%
print("Here are counts for other p and change cutoffs:")
print("P<0.05, >150% of the other type")
print(prot2.is_altered(tstats_2, pvalue=.05,change_factor=1.5,change_col=fc_comp_2, cell_types=cell_types).value_counts()) #50% increase from either
print("\nP<0.05, >200% of the other type")
print(prot2.is_altered(tstats_2, pvalue=.05,change_factor=2,change_col=fc_comp_2, cell_types=cell_types).value_counts()) #Double
print("\nP<0.05, >500% of the other type")
print(prot2.is_altered(tstats_2, pvalue=.05,change_factor=5,change_col=fc_comp_2, cell_types=cell_types).value_counts()) #5 times larger

print("\nP<0.01, >150% of the other type")
print(prot2.is_altered(tstats_2, pvalue=.01,change_factor=1.5,change_col=fc_comp_2, cell_types=cell_types).value_counts()) #50% increase from either
print("\nP<0.01, >200% of the other type")
print(prot2.is_altered(tstats_2, pvalue=.01,change_factor=2,change_col=fc_comp_2, cell_types=cell_types).value_counts()) #Double
print("\nP<0.01, >500% of the other type")
print(prot2.is_altered(tstats_2, pvalue=.01,change_factor=5,change_col=fc_comp_2, cell_types=cell_types).value_counts()) #5 times larger
# Out:
# Here are counts for other p and change cutoffs:
# P<0.05, >150% of the other type
# B_cells_072920    133
# B_cells_062920     31
# dtype: int64
#
# P<0.05, >200% of the other type
# B_cells_072920    42
# B_cells_062920    10
# dtype: int64
#
# P<0.05, >500% of the other type
# B_cells_072920    2
# B_cells_062920    1
# dtype: int64
#
# P<0.01, >150% of the other type
# B_cells_072920    105
# B_cells_062920     19
# dtype: int64
#
# P<0.01, >200% of the other type
# B_cells_072920    33
# B_cells_062920     8
# dtype: int64
#
# P<0.01, >500% of the other type
# B_cells_072920    2
# dtype: int64

# %% [markdown]
# ### Differentially expressed proteins

# %%
figure = sns.scatterplot(x=fc_comp,y='-log p',data=tstats)
figure2 = sns.scatterplot(x=fc_comp,y='-log p',
                          data=tstats.loc[altered.index])
plt.rc('axes',labelsize=16)
#plt.xticks(fontsize=14)
#plt.yticks(fontsize=14)
#plt.title("B cells vs T cells", fontsize=20)

#plt.savefig("data/0_v_30_sub1.png", bbox_inches='tight', dpi=300)

# %%
figure = sns.scatterplot(x=fc_comp_2,y='-log p',data=tstats_2)
figure2 = sns.scatterplot(x=fc_comp_2,y='-log p',
                          data=tstats_2.loc[altered_2.index])
plt.rc('axes',labelsize=16)
#plt.xticks(fontsize=14)
#plt.yticks(fontsize=14)
#plt.title("B cells vs T cells", fontsize=20)

#plt.savefig("data/0_v_30_sub2.png", bbox_inches='tight', dpi=300)

# %% [markdown]
# This shows the differentially expressed proteins. Recall that this dataset is restricted to those expressed in at least three of each cell type.
#
# The next step is to identify those proteins by name. Here we get the protein names from the fasta file, which remain the same regardless of which software the data was quantified using.

# %% [markdown]
# *Note that this function doesn't really have a place in the new set up yet.*

# %%
import pandas as pd
def load_fasta(file="data/uniprot-filtered-proteome_3AUP000005640_reviewed_human.fasta"):
    
    #file is formated:
    #>sp|Q96IY4|CBPB2_HUMAN Carboxypeptidase B2 OS=Homo sapiens OX=9606 GN=CPB2 PE=1 SV=2
    #MKLCS...
    headings = {}
    with open(file) as f:
        for line in f:
            if line.startswith('>'):#header line
                ID = line.split('|')[1]
                name=line.split('|')[2].split('=')[0].strip('OS')
                headings[ID]=name
    headings = pd.Series(list(headings.values()), index=headings.keys())
    
    return headings

# %%
protein_names = load_fasta()

# %%
import pandas as pd
protein_names_by_group={}
for ID in prot.data_raw.index:
    if ';' in ID:
        ids = ID.split(';')
        names=''
        for i in ids:
            if i in protein_names.index:
                names=names + protein_names[i] + ';'
        names = names[:-1]
        protein_names_by_group[ID] = names
    else:
        if ID in protein_names.index:
            protein_names_by_group[ID]=protein_names[ID]
protein_names_by_group = pd.Series(list(protein_names_by_group.values()), index=protein_names_by_group.keys())

# %%
protein_names_by_group_2={}
for ID in prot2.data_raw.index:
    if ';' in ID:
        ids = ID.split(';')
        names=''
        for i in ids:
            if i in protein_names.index:
                names=names + protein_names[i] + ';'
        names = names[:-1]
        protein_names_by_group_2[ID] = names
    else:
        if ID in protein_names.index:
            protein_names_by_group_2[ID]=protein_names[ID]
protein_names_by_group_2 = pd.Series(list(protein_names_by_group_2.values()), index=protein_names_by_group_2.keys())

# %% [markdown]
# Here we add the names to the <code>tstats</code> dataframe, which contains the fold changes for each protein. Then we can list the proteins that are altered. Optionally, use <code> head()</code> to display the first few or <code>to_csv</code> to write out to a file. We now split up the proteins heightened in B cells from those heightened in T cells.

# %%
tstats['Name']=protein_names_by_group
tstats['GeneID'] = tstats.Name.apply(lambda n: str(n).split('_HUMAN')[0])

altered_proteins = tstats.loc[altered.index].sort_values(fc_comp,
                        ascending=False)[['Name','GeneID',fc_comp,'pvalue']]
higher_in_group1 = altered_proteins.loc[altered_proteins[fc_comp] >0]
higher_in_group2 = altered_proteins.loc[altered_proteins[fc_comp] <0]

#To write out to a file, use:
#altered_proteins.to_csv('data/filename.tsv', sep='\t')

# %%
tstats_2['Name']=protein_names_by_group_2
tstats_2['GeneID'] = tstats_2.Name.apply(lambda n: str(n).split('_HUMAN')[0])

altered_proteins_2 = tstats_2.loc[altered_2.index].sort_values(fc_comp_2,
                        ascending=False)[['Name','GeneID',fc_comp_2,'pvalue']]
higher_in_group1_2 = altered_proteins_2.loc[altered_proteins_2[fc_comp_2] >0]
higher_in_group2_2 = altered_proteins_2.loc[altered_proteins_2[fc_comp_2] <0]

#To write out to a file, use:
#altered_proteins.to_csv('data/filename.tsv', sep='\t')

# %% [markdown]
# Next we do the same for those only identified in one cell type.

# %%
data_in_one_type['Name'] = protein_names_by_group
data_in_one_type['GeneID']=data_in_one_type.Name.apply(lambda n: str(n).split('_HUMAN')[0])

group1_only_geneset = data_in_one_type[(data_in_one_type.Type==cell_types[0])]
group2_only_geneset= data_in_one_type[(data_in_one_type.Type==cell_types[1])]

# %%
data_in_one_type_2['Name'] = protein_names_by_group_2
data_in_one_type_2['GeneID']=data_in_one_type_2.Name.apply(lambda n: str(n).split('_HUMAN')[0])

group1_only_geneset_2 = data_in_one_type_2[(data_in_one_type_2.Type==cell_types[0])]
group2_only_geneset_2= data_in_one_type_2[(data_in_one_type_2.Type==cell_types[1])]

# %% [markdown]
# ### Proteins Higher in June:

# %%
higher_in_group1
# Out:
#                                                          Name GeneID  \
# Protein ID
# O14745      NHRF1_HUMAN Na(+)/H(+) exchange regulatory cof...  NHRF1
# P02763               A1AG1_HUMAN Alpha-1-acid glycoprotein 1   A1AG1
# O75306      NDUS2_HUMAN NADH dehydrogenase [ubiquinone] ir...  NDUS2
# P14854          CX6B1_HUMAN Cytochrome c oxidase subunit 6B1   CX6B1
# P69892                 HBG2_HUMAN Hemoglobin subunit gamma-2    HBG2
# ...                                                       ...    ...
# P07741           APT_HUMAN Adenine phosphoribosyltransferase     APT
# Q14847              LASP1_HUMAN LIM and SH3 domain protein 1   LASP1
# P13639                         EF2_HUMAN Elongation factor 2     EF2
# P32969                    RL9_HUMAN 60S ribosomal protein L9     RL9
# Q9UJU6                       DBNL_HUMAN Drebrin-like protein    DBNL
#
#             log2(30)-log2(0)    pvalue
# Protein ID
# O14745              2.421507  0.008779
# P02763              2.179159  0.015043
# O75306              2.102583  0.024425
# P14854              1.482313  0.046868
# P69892              1.351113  0.042037
# ...                      ...       ...
# P07741              0.231686  0.032584
# Q14847              0.216764  0.034158
# P13639              0.194526  0.040831
# P32969              0.193292  0.044398
# Q9UJU6              0.173180  0.043022
#
# [118 rows x 4 columns]

# %%
higher_in_group1_2
# Out:
#                                                          Name GeneID  \
# Protein ID
# P02724                              GLPA_HUMAN Glycophorin-A    GLPA
# P26368       U2AF2_HUMAN Splicing factor U2AF 65 kDa subunit   U2AF2
# Q9H9B4                             FXN1_HUMAN Sideroflexin-1    FXN1
# P67809                   YBOX1_HUMAN Y-box-binding protein 1   YBOX1
# P04233      HG2A_HUMAN HLA class II histocompatibility ant...   HG2A
# ...                                                       ...    ...
# Q9Y490                                    TLN1_HUMAN Talin-1    TLN1
# P55072      TERA_HUMAN Transitional endoplasmic reticulum ...   TERA
# P11171                                  41_HUMAN Protein 4.1      41
# Q15365                PCBP1_HUMAN Poly(rC)-binding protein 1   PCBP1
# P15311                                      EZRI_HUMAN Ezrin    EZRI
#
#             log2(30)-log2(0)    pvalue
# Protein ID
# P02724              3.122357  0.002256
# P26368              2.533367  0.003469
# Q9H9B4              2.098472  0.042205
# P67809              2.073728  0.020918
# P04233              1.659774  0.001127
# ...                      ...       ...
# Q9Y490              0.195626  0.005746
# P55072              0.181269  0.048025
# P11171              0.160048  0.027341
# Q15365              0.157839  0.024876
# P15311              0.155937  0.038847
#
# [256 rows x 4 columns]

# %%
#sanity check with a couple proteins
#prot.data_frame.loc['P02775']

# %% [markdown]
# ### Proteins Only in June:

# %%
group1_only_geneset[['Name', 'GeneID']]
# Out:
#                                                          Name GeneID
# Protein ID
# O00161         NP23_HUMAN Synaptosomal-associated protein 23    NP23
# O00244            ATOX1_HUMAN Copper transport protein ATOX1   ATOX1
# O00442          RTCA_HUMAN RNA 3'-terminal phosphate cyclase    RTCA
# O43681                               ASNA_HUMAN ATPase ASNA1    ASNA
# O60610              DIAP1_HUMAN Protein diaphanous homolog 1   DIAP1
# ...                                                       ...    ...
# P28068      DMB_HUMAN HLA class II histocompatibility anti...    DMB
# P35030                                  TRY3_HUMAN Trypsin-3    TRY3
# P37235                HPCL1_HUMAN Hippocalcin-like protein 1   HPCL1
# P41567      EIF1_HUMAN Eukaryotic translation initiation f...   EIF1
# Q9Y3C4           TPRKB_HUMAN EKC/KEOPS complex subunit TPRKB   TPRKB
#
# [78 rows x 2 columns]

# %%
group1_only_geneset_2[['Name', 'GeneID']]
# Out:
#                                                          Name GeneID
# Protein ID
# O00244            ATOX1_HUMAN Copper transport protein ATOX1   ATOX1
# O43681                               ASNA_HUMAN ATPase ASNA1    ASNA
# P41252        YIC_HUMAN Isoleucine--tRNA ligase, cytoplasmic     YIC
# P48147                       PPCE_HUMAN Prolyl endopeptidase    PPCE
# P49589          YCC_HUMAN Cysteine--tRNA ligase, cytoplasmic     YCC
# P52306      GDS1_HUMAN Rap1 GTPase-GDP dissociation stimul...   GDS1
# Q13418              ILK_HUMAN Integrin-linked protein kinase     ILK
# Q15121          PEA15_HUMAN Astrocytic phosphoprotein PEA-15   PEA15
# Q16719                               KYNU_HUMAN Kynureninase    KYNU
# Q16775      GLO2_HUMAN Hydroxyacylglutathione hydrolase, m...   GLO2
# Q93009      UBP7_HUMAN Ubiquitin carboxyl-terminal hydrola...   UBP7
# Q9BY43      CHM4A_HUMAN Charged multivesicular body protei...  CHM4A
# Q9NP72                RAB18_HUMAN Ras-related protein Rab-18   RAB18
# Q9NZ01        TECR_HUMAN Very-long-chain enoyl-CoA reductase    TECR
# Q9Y2D5                 AKAP2_HUMAN A-kinase anchor protein 2   AKAP2
# Q9UNL2      RG_HUMAN Translocon-associated protein subunit...     RG
# P00846                     ATP6_HUMAN ATP synthase subunit a    ATP6

# %% [markdown]
# ### Proteins higher or only in June by GeneID
# <code>group1_set</code> is defined here as both the above lists of names, those higher or only in group 1 cells.
# Note that this might not be the most interesting set of proteins, ie, when comparing data that was not run together those that appear only in one time are much more likely to be run errors.

# %%
group1_set = list(higher_in_group1.GeneID)+list(group1_only_geneset.GeneID)

# %%
group1_set_2 = list(higher_in_group1_2.GeneID)+list(group1_only_geneset_2.GeneID)

# %% [markdown]
# ### Proteins Higher in July:

# %%
higher_in_group2.sort_values('pvalue', ascending=True)
# Out:
#                                                          Name GeneID  \
# Protein ID
# P40925          MDHC_HUMAN Malate dehydrogenase, cytoplasmic    MDHC
# P27695      APEX1_HUMAN DNA-(apurinic or apyrimidinic site...  APEX1
# Q9UII2           ATIF1_HUMAN ATPase inhibitor, mitochondrial   ATIF1
# P09960                 LKHA4_HUMAN Leukotriene A-4 hydrolase   LKHA4
# Q9UI08                       EVL_HUMAN Ena/VASP-like protein     EVL
# P56279       TCL1A_HUMAN T-cell leukemia/lymphoma protein 1A   TCL1A
# P22626      ROA2_HUMAN Heterogeneous nuclear ribonucleopro...   ROA2
# Q5SSJ5      HP1B3_HUMAN Heterochromatin protein 1-binding ...  HP1B3
# P61956         UMO2_HUMAN Small ubiquitin-related modifier 2    UMO2
# Q92522                                 H1X_HUMAN Histone H1x     H1X
# O14979      HNRDL_HUMAN Heterogeneous nuclear ribonucleopr...  HNRDL
# P31150       GDIA_HUMAN Rab GDP dissociation inhibitor alpha    GDIA
# P02545                               LMNA_HUMAN Prelamin-A/C    LMNA
# P19338                                  NUCL_HUMAN Nucleolin    NUCL
# P28062             PSB8_HUMAN Proteasome subunit beta type-8    PSB8
# P80723              BASP1_HUMAN Brain acid soluble protein 1   BASP1
# Q562R1                 ACTBL_HUMAN Beta-actin-like protein 2   ACTBL
# Q03252                                  LMNB2_HUMAN Lamin-B2   LMNB2
# P50452                                   PB8_HUMAN Serpin B8     PB8
# P31146                                COR1A_HUMAN Coronin-1A   COR1A
# Q96JE7           C16B_HUMAN Protein transport protein Sec16B    C16B
# O95758      PTBP3_HUMAN Polypyrimidine tract-binding prote...  PTBP3
# Q9Y2S6      TMA7_HUMAN Translation machinery-associated pr...   TMA7
# Q14103      HNRPD_HUMAN Heterogeneous nuclear ribonucleopr...  HNRPD
# P27348                      1433T_HUMAN 14-3-3 protein theta   1433T
# O15400                                  TX7_HUMAN Syntaxin-7     TX7
# P11279      LAMP1_HUMAN Lysosome-associated membrane glyco...  LAMP1
# P84243                                H33_HUMAN Histone H3.3     H33
# P01903      DRA_HUMAN HLA class II histocompatibility anti...    DRA
# P05114      HMGN1_HUMAN Non-histone chromosomal protein HM...  HMGN1
# P62081                    RS7_HUMAN 40S ribosomal protein S7     RS7
# P06748                               NPM_HUMAN Nucleophosmin     NPM
# P39687      AN32A_HUMAN Acidic leucine-rich nuclear phosph...  AN32A
# O00571          DDX3X_HUMAN ATP-dependent RNA helicase DDX3X   DDX3X
# P0DOY2          IGLC2_HUMAN Immunoglobulin lambda constant 2   IGLC2
# P62328                            TYB4_HUMAN Thymosin beta-4    TYB4
# P30048      PRDX3_HUMAN Thioredoxin-dependent peroxide red...  PRDX3
# P13796                                  PLSL_HUMAN Plastin-2    PLSL
# P05387            RLA2_HUMAN 60S acidic ribosomal protein P2    RLA2
# P26599      PTBP1_HUMAN Polypyrimidine tract-binding prote...  PTBP1
# O60493                             NX3_HUMAN Sorting nexin-3     NX3
# P35527             K1C9_HUMAN Keratin, type I cytoskeletal 9    K1C9
# P23497                 P100_HUMAN Nuclear autoantigen Sp-100    P100
# P25787            PSA2_HUMAN Proteasome subunit alpha type-2    PSA2
# O75367                   H2AY_HUMAN Core histone macro-H2A.1    H2AY
# P00491            PNPH_HUMAN Purine nucleoside phosphorylase    PNPH
# Q71DI3                                H32_HUMAN Histone H3.2     H32
# P68431                                H31_HUMAN Histone H3.1     H31
# P55263                            ADK_HUMAN Adenosine kinase     ADK
# P29508                                   PB3_HUMAN Serpin B3     PB3
#
#             log2(30)-log2(0)    pvalue
# Protein ID
# P40925             -0.697160  0.000072
# P27695             -0.714168  0.000076
# Q9UII2             -1.155283  0.000138
# P09960             -0.486866  0.000316
# Q9UI08             -0.573145  0.000534
# P56279             -1.367644  0.000978
# P22626             -0.391689  0.001100
# Q5SSJ5             -0.373794  0.001354
# P61956             -0.998122  0.001437
# Q92522             -0.945849  0.001721
# O14979             -0.741820  0.002032
# P31150             -0.426028  0.002105
# P02545             -1.323313  0.003027
# P19338             -0.575978  0.003579
# P28062             -0.836701  0.003627
# P80723             -0.524138  0.003710
# Q562R1             -0.481293  0.004549
# Q03252             -0.364407  0.005372
# P50452             -1.031299  0.007051
# P31146             -0.266249  0.008513
# Q96JE7             -0.578946  0.008633
# O95758             -0.807682  0.009382
# Q9Y2S6             -0.452812  0.009501
# Q14103             -0.577587  0.009776
# P27348             -0.303326  0.010550
# O15400             -0.827576  0.010951
# P11279             -0.618533  0.011641
# P84243             -0.591614  0.011863
# P01903             -0.439124  0.011915
# P05114             -0.465116  0.017358
# P62081             -0.332155  0.018246
# P06748             -0.555314  0.018818
# P39687             -0.666261  0.018893
# O00571             -0.843072  0.019564
# P0DOY2             -0.826326  0.022483
# P62328             -0.329898  0.022886
# P30048             -0.868514  0.024270
# P13796             -0.511349  0.025458
# P05387             -0.991500  0.026815
# P26599             -0.473579  0.030043
# O60493             -0.446077  0.032081
# P35527             -1.699721  0.032449
# P23497             -0.569253  0.036142
# P25787             -0.977536  0.036548
# O75367             -0.195983  0.037900
# P00491             -0.927830  0.042794
# Q71DI3             -0.486497  0.045601
# P68431             -0.486497  0.045601
# P55263             -0.578616  0.047041
# P29508             -0.858792  0.049556

# %%
higher_in_group2_2.sort_values('pvalue', ascending=True)
# Out:
#                                                          Name GeneID  \
# Protein ID
# Q92522                                 H1X_HUMAN Histone H1x     H1X
# P40925          MDHC_HUMAN Malate dehydrogenase, cytoplasmic    MDHC
# Q96G03                       PGM2_HUMAN Phosphoglucomutase-2    PGM2
# P09960                 LKHA4_HUMAN Leukotriene A-4 hydrolase   LKHA4
# P98179                      RBM3_HUMAN RNA-binding protein 3    RBM3
# ...                                                       ...    ...
# P63279               UBC9_HUMAN SUMO-conjugating enzyme UBC9    UBC9
# P05455                             LA_HUMAN Lupus La protein      LA
# P07384                CAN1_HUMAN Calpain-1 catalytic subunit    CAN1
# Q06187                 BTK_HUMAN Tyrosine-protein kinase BTK     BTK
# Q9Y6N5      QOR_HUMAN Sulfide:quinone oxidoreductase, mito...    QOR
#
#             log2(30)-log2(0)    pvalue
# Protein ID
# Q92522             -1.330087  0.000002
# P40925             -1.025734  0.000007
# Q96G03             -0.967926  0.000020
# P09960             -0.911815  0.000026
# P98179             -1.137013  0.000094
# ...                      ...       ...
# P63279             -0.570989  0.044678
# P05455             -0.844461  0.046864
# P07384             -0.279988  0.047084
# Q06187             -0.359889  0.047263
# Q9Y6N5             -0.333314  0.049779
#
# [84 rows x 4 columns]

# %% [markdown]
# ### Proteins Only in July:

# %%
group2_only_geneset[['Name', 'GeneID']]
# Out:
#                                                          Name GeneID
# Protein ID
# O95969           G1D2_HUMAN Secretoglobin family 1D member 2    G1D2
# P01833          PIGR_HUMAN Polymeric immunoglobulin receptor    PIGR
# P02814      MR3B_HUMAN Submaxillary gland androgen-regulat...   MR3B
# P28799                                 GRN_HUMAN Progranulin     GRN
# P47929                                 LEG7_HUMAN Galectin-7    LEG7
# Q6VY07      PACS1_HUMAN Phosphofurin acidic cluster sortin...  PACS1
# Q8TAX7                                    MUC7_HUMAN Mucin-7    MUC7
# Q9H1E5      TMX4_HUMAN Thioredoxin-related transmembrane p...   TMX4
# Q9UGM3      DMBT1_HUMAN Deleted in malignant brain tumors ...  DMBT1
# Q5VSP4       LC1L1_HUMAN Putative lipocalin 1-like protein 1   LC1L1
# P02808                                   TAT_HUMAN Statherin     TAT
# Q04941                      PLP2_HUMAN Proteolipid protein 2    PLP2

# %%
group2_only_geneset_2[['Name', 'GeneID']]
# Out:
#                                                          Name GeneID
# Protein ID
# O95969           G1D2_HUMAN Secretoglobin family 1D member 2    G1D2
# P01833          PIGR_HUMAN Polymeric immunoglobulin receptor    PIGR
# P02814      MR3B_HUMAN Submaxillary gland androgen-regulat...   MR3B
# Q8TAX7                                    MUC7_HUMAN Mucin-7    MUC7
# Q9UGM3      DMBT1_HUMAN Deleted in malignant brain tumors ...  DMBT1
# P02808                                   TAT_HUMAN Statherin     TAT

# %% [markdown]
# ### Proteins higher or only in July by GeneID
# <code>group2_set</code> is defined here as both the above lists of names, those higher or only in T cells.

# %%
group2_set = list(higher_in_group2.GeneID)+list(group2_only_geneset.GeneID)

# %%
group2_set_2 = list(higher_in_group2_2.GeneID)+list(group2_only_geneset_2.GeneID)

# %% [markdown]
# ## Suplementary Table: Distinguished Proteins
# Here we combine the data from the four categories in one dataframe and output it to a tab-separated file.

# %% [markdown]
# First, we get the names of the distinguished proteins.

# %%
distinguished_proteins = pd.concat([higher_in_group1, higher_in_group2])

# %%
distinguished_proteins_2 = pd.concat([higher_in_group1_2, higher_in_group2_2])

# %%
distinguished_proteins
# Out:
#                                                          Name GeneID  \
# Protein ID
# O14745      NHRF1_HUMAN Na(+)/H(+) exchange regulatory cof...  NHRF1
# P02763               A1AG1_HUMAN Alpha-1-acid glycoprotein 1   A1AG1
# O75306      NDUS2_HUMAN NADH dehydrogenase [ubiquinone] ir...  NDUS2
# P14854          CX6B1_HUMAN Cytochrome c oxidase subunit 6B1   CX6B1
# P69892                 HBG2_HUMAN Hemoglobin subunit gamma-2    HBG2
# ...                                                       ...    ...
# P50452                                   PB8_HUMAN Serpin B8     PB8
# Q9UII2           ATIF1_HUMAN ATPase inhibitor, mitochondrial   ATIF1
# P02545                               LMNA_HUMAN Prelamin-A/C    LMNA
# P56279       TCL1A_HUMAN T-cell leukemia/lymphoma protein 1A   TCL1A
# P35527             K1C9_HUMAN Keratin, type I cytoskeletal 9    K1C9
#
#             log2(30)-log2(0)    pvalue
# Protein ID
# O14745              2.421507  0.008779
# P02763              2.179159  0.015043
# O75306              2.102583  0.024425
# P14854              1.482313  0.046868
# P69892              1.351113  0.042037
# ...                      ...       ...
# P50452             -1.031299  0.007051
# Q9UII2             -1.155283  0.000138
# P02545             -1.323313  0.003027
# P56279             -1.367644  0.000978
# P35527             -1.699721  0.032449
#
# [168 rows x 4 columns]

# %%
distinguished_proteins_2
# Out:
#                                                          Name GeneID  \
# Protein ID
# P02724                              GLPA_HUMAN Glycophorin-A    GLPA
# P26368       U2AF2_HUMAN Splicing factor U2AF 65 kDa subunit   U2AF2
# Q9H9B4                             FXN1_HUMAN Sideroflexin-1    FXN1
# P67809                   YBOX1_HUMAN Y-box-binding protein 1   YBOX1
# P04233      HG2A_HUMAN HLA class II histocompatibility ant...   HG2A
# ...                                                       ...    ...
# O43399                         TPD54_HUMAN Tumor protein D54   TPD54
# Q07812                     BAX_HUMAN Apoptosis regulator BAX     BAX
# Q92522                                 H1X_HUMAN Histone H1x     H1X
# P56279       TCL1A_HUMAN T-cell leukemia/lymphoma protein 1A   TCL1A
# Q96Q89               KI20B_HUMAN Kinesin-like protein KIF20B   KI20B
#
#             log2(30)-log2(0)    pvalue
# Protein ID
# P02724              3.122357  0.002256
# P26368              2.533367  0.003469
# Q9H9B4              2.098472  0.042205
# P67809              2.073728  0.020918
# P04233              1.659774  0.001127
# ...                      ...       ...
# O43399             -1.174742  0.011620
# Q07812             -1.192345  0.006341
# Q92522             -1.330087  0.000002
# P56279             -1.575643  0.000393
# Q96Q89             -3.099123  0.013440
#
# [340 rows x 4 columns]

# %% [markdown]
# Next, we get the intensity data for these proteins.

# %%
altered_data = prot.data_frame.loc[distinguished_proteins.index]

# %%
altered_data_2 = prot2.data_frame.loc[distinguished_proteins_2.index]

# %% [markdown]
# Next, we average by cell type, creating new columns in our <code>distinguished_proteins</code> dataframe.

# %%
import numpy as np
samples=np.array(prot.data_raw.columns.values)

from statistics import mean

def mean_noNan(ser):
    ser = ser.dropna()
    if len(ser)==0:
        return np.nan
    return mean(ser)

for cell_type in cell_types:
    cells_of_type = list(s for i,s in enumerate(samples) if cell_type in s)
    type_data = altered_data[cells_of_type]
    means = type_data.apply(mean_noNan, axis=1)
    
    distinguished_proteins[("Mean {0}".format(cell_type))] = means

# %%
samples_2=np.array(prot2.data_raw.columns.values)

for cell_type in cell_types:
    cells_of_type = list(s for i,s in enumerate(samples_2) if cell_type in s)
    type_data = altered_data_2[cells_of_type]
    means = type_data.apply(mean_noNan, axis=1)
    
    distinguished_proteins_2[("Mean {0}".format(cell_type))] = means

# %% [markdown]
# Here we check the column order and rearrange it as we like.

# %%
distinguished_proteins.columns
# Out:
# Index(['Name', 'GeneID', 'log2(30)-log2(0)', 'pvalue', 'Mean B_cells_072920',
#        'Mean B_cells_062920'],
#       dtype='object')

# %%
distinguished_proteins_2.columns
# Out:
# Index(['Name', 'GeneID', 'log2(30)-log2(0)', 'pvalue', 'Mean B_cells_072920',
#        'Mean B_cells_062920'],
#       dtype='object')

# %%
distinguished_proteins = distinguished_proteins[["GeneID", "Mean B_cells_062920", "Mean B_cells_072920", "log2(30)-log2(0)", "pvalue"]]

# %%
distinguished_proteins_2 = distinguished_proteins_2[["GeneID", "Mean B_cells_062920", "Mean B_cells_072920", "log2(30)-log2(0)", "pvalue"]]

# %% [markdown]
# Here we sort the proteins. This will sort them such that high abundance in B come first, down it low abundance in B, and finally sorting the T only proteins from low to high.

# %%
distinguished_proteins.sort_values(["Mean B_cells_062920", "Mean B_cells_072920"], ascending=[False, False], inplace=True)
# Out:
# <ipython-input-67-850e92c8ccdf>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   distinguished_proteins.sort_values(["Mean B_cells_062920", "Mean B_cells_072920"], ascending=[False, False], inplace=True)

# %%
distinguished_proteins_2.sort_values(["Mean B_cells_062920", "Mean B_cells_072920"], ascending=[False, False], inplace=True)
# Out:
# <ipython-input-68-98fd0e6fd0e1>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   distinguished_proteins_2.sort_values(["Mean B_cells_062920", "Mean B_cells_072920"], ascending=[False, False], inplace=True)

# %% [markdown]
# Finally, we have the finished dataframe.

# %%
#distinguished_proteins
dp = distinguished_proteins['pvalue']
dp
# Out:
# Protein ID
# P69905    0.006810
# P04908    0.009530
# P0C0S8    0.006864
# Q16777    0.003120
# P69891    0.042088
#             ...
# O95861    0.032936
# P55036    0.002686
# P46459    0.036025
# O75306    0.024425
# O14745    0.008779
# Name: pvalue, Length: 168, dtype: float64

# %%
distinguished_proteins_2
dp_2 = distinguished_proteins_2['pvalue']
dp_2
# Out:
# Protein ID
# P68871    0.000107
# Q8IUE6    0.005956
# P02042    0.000093
# P06899    0.000101
# O60814    0.000135
#             ...
# P07948    0.011124
# P39748    0.008024
# P33992    0.005560
# P26196    0.033027
# Q9H9B4    0.042205
# Name: pvalue, Length: 340, dtype: float64

# %%
sub1_v_2_intersection = set(prot.data_raw.index).intersection(set(prot2.data_raw.index))
#mj_intersection = set(j_p.index).intersection(set(mayer_p.index))

# %%
significant_in_either = sub1_v_2_intersection.intersection(set(distinguished_proteins.index)).union(
    sub1_v_2_intersection.intersection(set(distinguished_proteins_2.index)))

# %%
len(sub1_v_2_intersection.intersection(set(distinguished_proteins.index)))
# Out:
# 168

# %%
len(sub1_v_2_intersection.intersection(set(distinguished_proteins_2.index)))
# Out:
# 340

# %%
len(significant_in_either)
# Out:
# 425

# %%
import matplotlib.pyplot as plt
from matplotlib_venn import venn2
from matplotlib_venn import venn3
venn2(subsets = (set(distinguished_proteins.index), set(distinguished_proteins_2.index)), set_labels = ('Subject 1', 'Subject 2'))
#plt.savefig('data/subject_comp_venn')
plt.show()

# %%
venn2(subsets = (set(sub1_v_2_intersection), set(significant_in_either)), set_labels = ('Subject 1', 'Subject 2'))
plt.show()

# %%
a = set(tstats.index)
b = set(tstats_2.index)

# %%
df_sub1_v_2_pvals_sig_in_either = pd.DataFrame(index = list(significant_in_either), columns = 
                           ['subject1 -log10(pvalue)', 'subject2 -log10(pvalue)'])

for i in significant_in_either:
    if i in a:
        val = tstats.loc[i]['pvalue']
        df_sub1_v_2_pvals_sig_in_either.loc[i, 'subject1 -log10(pvalue)'] = -log10(val)#since this is p and the other is -log(p)
    else:
        print(i)
    if i in b:
        val = tstats_2.loc[i]['pvalue']
       # print(val)
        df_sub1_v_2_pvals_sig_in_either.loc[i, 'subject2 -log10(pvalue)'] = -log10(val)
    else:
        print(i + "_2")
       # -log10(tstats_2['pvalue'])
#df_junejuly_pvals_sig_in_either.dropna()
# Out:
# P29218_2
# P14324
# P49257
# Q9H9B4
# Q9Y4L1
# P13693
# P02763_2
# P33992

# %%
print(len(set(df_sub1_v_2_pvals_sig_in_either['subject1 -log10(pvalue)'])))
# Out:
# 419

# %%
#plt.figure(figsize=(6, 6))
df_sub1_v_2_pvals_sig_in_either.plot.scatter('subject1 -log10(pvalue)', 'subject2 -log10(pvalue)')
plt.axhline(-log10(.05), color ='orange')
plt.axvline(-log10(.05), color ='orange')

#fig.addsubplot(111).set_aspect('equal', adjustable='box')
#plt.savefig('test.png', dpi=300)
#plt.savefig('data/changes_in_subjects_2.png')

# %%
import seaborn as sns

# %%
fig = plt.figure()
ax = fig.add_subplot(111, aspect='equal')
sns.scatterplot(data=df_sub1_v_2_pvals_sig_in_either, x='subject1 -log10(pvalue)', y='subject2 -log10(pvalue)')
 
# control x and y limits
plt.ylim(0, 7)
plt.xlim(0, 7)
plt.axhline(-log10(.05), color ='orange')
plt.axvline(-log10(.05), color ='orange')

plt.rc('axes',labelsize=16)
#plt.savefig('test.png', dpi=300)

# %%
venn3(subsets = (set(distinguished_proteins.index), set(distinguished_proteins_2.index), set(sub1_v_2_intersection)), set_labels = ('sub 1', 'sub 2', 'both'))
plt.show()

# %%
df_sub1_v_2_pvals_sig_in_either = pd.DataFrame(index = list(significant_in_either), columns = 
                           ['subject1 -log10(pvalue)', 'subject2 -log10(pvalue)'])

for i in sub1_v_2_intersection:
    if i in a:
        val = tstats.loc[i]['pvalue']
        df_sub1_v_2_pvals_sig_in_either.loc[i, 'subject1 -log10(pvalue)'] = -log10(val)#since this is p and the other is -log(p)
    else:
        print(i)
    if i in b:
        val = tstats_2.loc[i]['pvalue']
       # print(val)
        df_sub1_v_2_pvals_sig_in_either.loc[i, 'subject2 -log10(pvalue)'] = -log10(val)
    else:
        print(i + "_2")
       # -log10(tstats_2['pvalue'])
#df_junejuly_pvals_sig_in_either.dropna()
# Out:
# Q6P2Q9
# Q6P2Q9_2
# Q9C075
# Q9C075_2
# Q8WXH0
# Q8WXH0_2
# Q16401
# Q16401_2
# O75489
# O14964
# O14964_2
# P30405
# P30405_2
# O00410
# Q0VGL1
# Q0VGL1_2
# Q08AF3
# Q08AF3_2
# O94826
# O94826_2
# P24855
# P24855_2
# P48506
# P48506_2
# Q15843
# Q15843_2
# Q10713
# Q10713_2
# P02814
# P02814_2
# P80217
# P80217_2
# P42229
# P42229_2
# P25774
# P25774_2
# P49721
# P49721_2
# P01137
# P01137_2
# P11678
# P11678_2
# A0A075B6K5_2
# O95810
# O95810_2
# Q05315
# Q05315_2
# P02810
# P02810_2
# P02749
# P02749_2
# P07359
# P07359_2
# Q9Y2V2
# Q9Y2V2_2
# Q92905
# Q92905_2
# Q9H444
# Q9BQ50
# Q9BQ50_2
# Q6VY07
# Q6VY07_2
# P01023
# P01023_2
# O60927
# O60927_2
# Q13098
# Q13098_2
# P06239
# P06239_2
# Q13045
# P42785
# P42785_2
# Q9UBW5
# Q9UBW5_2
# P05107
# P05107_2
# Q8IZP0
# Q8IZP0_2
# P35250
# P35250_2
# Q9BXS5_2
# O43852
# O43852_2
# Q99808_2
# Q9UHR5
# Q9UHR5_2
# P56556
# P12955
# P12955_2
# Q9BSH4
# Q9BSH4_2
# O75521
# O75521_2
# Q69YN2
# Q69YN2_2
# O76003
# O76003_2
# P28331
# Q9P0J1
# Q9P0J1_2
# Q16740
# Q16740_2
# O75915_2
# P36543
# P36543_2
# Q9H0A0
# Q9H0A0_2
# Q00169
# Q00169_2
# P19971
# Q92878
# Q02094
# Q02094_2
# Q9Y3P8
# Q9Y3P8_2
# P02441
# P02441_2
# Q92506
# Q92506_2
# Q9UPT8
# Q9UPT8_2
# P49913
# P49913_2
# P01012
# P01012_2
# Q8NB37
# Q8NB37_2
# P10909
# P10909_2
# Q16378
# Q16378_2
# Q9NPF4
# Q9NPF4_2
# O60885
# O60885_2
# Q16186
# Q16186_2
# P10415
# P10415_2
# Q53TN4
# Q53TN4_2
# Q9UJY4
# Q9UJY4_2
# P23381
# Q0VD83
# Q0VD83_2
# Q9BQA1
# Q9BQA1_2
# O75934
# O75934_2
# Q13596
# Q13596_2
# P49593
# P49593_2
# P49585
# P49585_2
# O60711
# O60711_2
# Q9UL25
# P18754
# Q8WWM7
# Q8WUM0
# Q8WUM0_2
# O14618_2
# Q9NYB0
# Q9NYB0_2
# Q5TDH0_2
# Q9BV68
# Q9BV68_2

# %%
print(len(set(df_sub1_v_2_pvals_sig_in_either['subject1 -log10(pvalue)'])))
# Out:
# 1122

# %%
df_sub1_v_2_pvals_sig_in_either.plot.scatter('subject1 -log10(pvalue)', 'subject2 -log10(pvalue)')
plt.axhline(-log10(.05), color ='orange')
plt.axvline(-log10(.05), color ='orange')
#plt.savefig('data/changes_in_subjects.png')

# %%
fig = plt.figure()
ax = fig.add_subplot(111, aspect='equal')
sns.scatterplot(data=df_sub1_v_2_pvals_sig_in_either, x='subject1 -log10(pvalue)', y='subject2 -log10(pvalue)')
 
# control x and y limits
plt.ylim(-0.1, 7)
plt.xlim(-0.1, 7)
plt.axhline(-log10(.05), color ='orange')
plt.axvline(-log10(.05), color ='orange')

plt.rc('axes',labelsize=16)

# %%
#from scipy import stats
#stats.pearsonr(df_junejuly_pvals_sig_in_either['subject1 -log10(pvalue)'], df_junejuly_pvals_sig_in_either['subject2 -log10(pvalue)'])

# %% [markdown]
# The last step is saving this dataframe to a file.

# %%
#distinguished_proteins.to_csv('data/distinguished_proteins_Sub1B_Day0_vs30_FP_noMBR.tsv', sep='\t')
