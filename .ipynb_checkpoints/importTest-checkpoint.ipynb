# %% [markdown]
# # Importing and downloading datasets
#
# The longitudinalCLL package is designed to help you access clinical, blood cell count, proteomic and metabolic data for a longitudinal chronic lymphocytic leukemia study. Some of this data is password protected, therefore if you would like to have full access to all this package has to offer, please contact the Payne lab at BYU.
#
# Here are some examples on how to download the datasets initially:

# %%
import longitudinalCLL

metab = longitudinalCLL.get_metabolic()
metab.load_dataset()
# Out:
#     subject       date  Na mmol/L  K mmol/L  Cl mmol/L  ECO2 mmol/L  \
# 0         1 2019-10-25        NaN       NaN        NaN          NaN
# 1         1 2019-11-22        NaN       NaN        NaN          NaN
# 2         1 2019-12-19      138.0       4.1      103.0         26.1
# 3         1 2020-01-31      140.0       3.7      104.0         26.2
# 4         1 2020-02-14      140.0       3.9      102.0         27.1
# 5         1 2020-02-21      139.0       3.8      102.0         26.4
# 6         1 2020-03-26      139.0       4.4      100.0         22.0
# 7         1 2020-06-29      141.0       4.0      103.0         21.0
# 8         1 2020-07-29      140.0       4.2      100.0         21.0
# 9         1 2020-09-17      140.0       4.2      102.0         25.0
# 10        1 2020-10-15      139.0       4.4      101.0         26.0
# 11        1 2020-11-12      137.0       4.3      100.0         25.0
# 0         2 2019-10-25        NaN       NaN        NaN          NaN
# 1         2 2019-11-22        NaN       NaN        NaN          NaN
# 2         2 2019-12-19      140.0       4.2      104.0         29.0
# 3         2 2020-01-31      142.0       4.0      105.0         27.9
# 4         2 2020-02-21      140.0       4.1      104.0         27.7
# 5         2 2020-06-29      139.0       4.3      102.0         23.0
# 6         2 2020-07-29      140.0       4.3       99.0         24.0
# 7         2 2020-09-17      143.0       4.8      102.0         26.0
# 8         2 2020-10-15      140.0       4.3      101.0         26.0
# 9         2 2020-11-12      140.0       4.6      100.0         29.0
#
#     AGAP mmol/L  AHDL mg/dL  VLDL mg/dL  LDL mg/dL  ...  A/G  GLUC mg/dL  \
# 0           NaN        43.0         NaN        NaN  ...  NaN          95
# 1           NaN        40.0         NaN        NaN  ...  NaN          94
# 2          13.0        42.0         NaN        NaN  ...  1.2          95
# 3          13.5        40.0         NaN        NaN  ...  1.3          95
# 4          14.8        42.0         NaN        NaN  ...  1.5          99
# 5          14.4        47.0         NaN        NaN  ...  1.4          97
# 6           NaN         NaN         NaN        NaN  ...  2.3          89
# 7           NaN        40.0        39.0      139.0  ...  2.4          85
# 8           NaN        42.0        58.0      120.0  ...  2.4          85
# 9           NaN        39.0        60.0      133.0  ...  2.4          90
# 10          NaN        38.0        53.0      120.0  ...  2.4          89
# 11          NaN        35.0        67.0      144.0  ...  2.2          88
# 0           NaN        34.0         NaN        NaN  ...  NaN         137
# 1           NaN        32.0         NaN        NaN  ...  NaN         105
# 2          11.2        36.0         NaN        NaN  ...  1.1         115
# 3          13.1        34.0         NaN        NaN  ...  1.2         113
# 4          12.4        32.0         NaN        NaN  ...  1.2         109
# 5           NaN        31.0        24.0      103.0  ...  2.0          92
# 6           NaN        27.0        36.0      136.0  ...  1.9          93
# 7           NaN        35.0        21.0      153.0  ...  2.2          73
# 8           NaN        32.0        25.0      142.0  ...  2.0         100
# 9           NaN        35.0        20.0      148.0  ...  1.9          79
#
#     BUN mg/dL  CA mg/dL  CRE2 mg/dL  BN/CR  eGFR NonAfrican Am  eGFR African  \
# 0         NaN       NaN         NaN    NaN                 NaN           NaN
# 1         NaN       NaN         NaN    NaN                 NaN           NaN
# 2        18.0       8.8        1.00   18.0                 NaN           NaN
# 3        14.0       8.6        1.00   14.0                 NaN           NaN
# 4        13.0       8.6        0.90   14.4                 NaN           NaN
# 5        16.0       8.8        0.90   17.8                 NaN           NaN
# 6        17.0      10.0        1.00   17.0                92.0           NaN
# 7        18.0       9.3        1.21   15.0                73.0          84.0
# 8        12.0       9.6        0.98   12.0                94.0         109.0
# 9        14.0       9.6        0.98   14.0                94.0         109.0
# 10       14.0       9.2        0.92   15.0               102.0         117.0
# 11       14.0       9.5        1.06   13.0                86.0          99.0
# 0         NaN       NaN         NaN    NaN                 NaN           NaN
# 1         NaN       NaN         NaN    NaN                 NaN           NaN
# 2        13.0       8.8        1.00   13.0                 NaN           NaN
# 3        21.0       9.0        1.20   17.5                 NaN           NaN
# 4        22.0       8.5        1.40   15.7                 NaN           NaN
# 5        15.0       9.2        0.95   19.0                 NaN           NaN
# 6        12.0       9.1        1.13   11.0                72.0          83.0
# 7        17.0       9.7        1.24   14.0                64.0          74.0
# 8        12.0       9.0        1.01   12.0                82.0          94.0
# 9        14.0       9.7        1.11   13.0                73.0          84.0
#
#     bilirubin mg/dL  Testing
# 0               NaN   BYU SHC
# 1               NaN   BYU SHC
# 2               NaN   BYU SHC
# 3               NaN   BYU SHC
# 4               NaN   BYU SHC
# 5               NaN   BYU SHC
# 6              0.60   LabCorp
# 7              0.03   LabCorp
# 8              0.30   LabCorp
# 9              0.40   LabCorp
# 10             0.40   LabCorp
# 11             0.06   LabCorp
# 0               NaN   BYU SHC
# 1               NaN   BYU SHC
# 2               NaN   BYU SHC
# 3               NaN   BYU SHC
# 4               NaN   BYU SHC
# 5              0.20   LabCorp
# 6              0.05   LabCorp
# 7              0.07   LabCorp
# 8              0.70   LabCorp
# 9              0.60   LabCorp
#
# [22 rows x 29 columns]

# %% [markdown]
# This is an example of how to load a dataset. This can be repeated for get_proteomic, get_clinical and get_cbc for their respective data. These getters return an object of type Metabolic, Proteomic, Clinical or CBC, depending on which getter you use. The load_dataset function returns a pandas data frame object while also saving the data frame as a member variable of said object. Thus we can access the dataframe after downloading with the following command:

# %%
metab.data_frame
# Out:
#     subject       date  Na mmol/L  K mmol/L  Cl mmol/L  ECO2 mmol/L  \
# 0         1 2019-10-25        NaN       NaN        NaN          NaN
# 1         1 2019-11-22        NaN       NaN        NaN          NaN
# 2         1 2019-12-19      138.0       4.1      103.0         26.1
# 3         1 2020-01-31      140.0       3.7      104.0         26.2
# 4         1 2020-02-14      140.0       3.9      102.0         27.1
# 5         1 2020-02-21      139.0       3.8      102.0         26.4
# 6         1 2020-03-26      139.0       4.4      100.0         22.0
# 7         1 2020-06-29      141.0       4.0      103.0         21.0
# 8         1 2020-07-29      140.0       4.2      100.0         21.0
# 9         1 2020-09-17      140.0       4.2      102.0         25.0
# 10        1 2020-10-15      139.0       4.4      101.0         26.0
# 11        1 2020-11-12      137.0       4.3      100.0         25.0
# 0         2 2019-10-25        NaN       NaN        NaN          NaN
# 1         2 2019-11-22        NaN       NaN        NaN          NaN
# 2         2 2019-12-19      140.0       4.2      104.0         29.0
# 3         2 2020-01-31      142.0       4.0      105.0         27.9
# 4         2 2020-02-21      140.0       4.1      104.0         27.7
# 5         2 2020-06-29      139.0       4.3      102.0         23.0
# 6         2 2020-07-29      140.0       4.3       99.0         24.0
# 7         2 2020-09-17      143.0       4.8      102.0         26.0
# 8         2 2020-10-15      140.0       4.3      101.0         26.0
# 9         2 2020-11-12      140.0       4.6      100.0         29.0
#
#     AGAP mmol/L  AHDL mg/dL  VLDL mg/dL  LDL mg/dL  ...  A/G  GLUC mg/dL  \
# 0           NaN        43.0         NaN        NaN  ...  NaN          95
# 1           NaN        40.0         NaN        NaN  ...  NaN          94
# 2          13.0        42.0         NaN        NaN  ...  1.2          95
# 3          13.5        40.0         NaN        NaN  ...  1.3          95
# 4          14.8        42.0         NaN        NaN  ...  1.5          99
# 5          14.4        47.0         NaN        NaN  ...  1.4          97
# 6           NaN         NaN         NaN        NaN  ...  2.3          89
# 7           NaN        40.0        39.0      139.0  ...  2.4          85
# 8           NaN        42.0        58.0      120.0  ...  2.4          85
# 9           NaN        39.0        60.0      133.0  ...  2.4          90
# 10          NaN        38.0        53.0      120.0  ...  2.4          89
# 11          NaN        35.0        67.0      144.0  ...  2.2          88
# 0           NaN        34.0         NaN        NaN  ...  NaN         137
# 1           NaN        32.0         NaN        NaN  ...  NaN         105
# 2          11.2        36.0         NaN        NaN  ...  1.1         115
# 3          13.1        34.0         NaN        NaN  ...  1.2         113
# 4          12.4        32.0         NaN        NaN  ...  1.2         109
# 5           NaN        31.0        24.0      103.0  ...  2.0          92
# 6           NaN        27.0        36.0      136.0  ...  1.9          93
# 7           NaN        35.0        21.0      153.0  ...  2.2          73
# 8           NaN        32.0        25.0      142.0  ...  2.0         100
# 9           NaN        35.0        20.0      148.0  ...  1.9          79
#
#     BUN mg/dL  CA mg/dL  CRE2 mg/dL  BN/CR  eGFR NonAfrican Am  eGFR African  \
# 0         NaN       NaN         NaN    NaN                 NaN           NaN
# 1         NaN       NaN         NaN    NaN                 NaN           NaN
# 2        18.0       8.8        1.00   18.0                 NaN           NaN
# 3        14.0       8.6        1.00   14.0                 NaN           NaN
# 4        13.0       8.6        0.90   14.4                 NaN           NaN
# 5        16.0       8.8        0.90   17.8                 NaN           NaN
# 6        17.0      10.0        1.00   17.0                92.0           NaN
# 7        18.0       9.3        1.21   15.0                73.0          84.0
# 8        12.0       9.6        0.98   12.0                94.0         109.0
# 9        14.0       9.6        0.98   14.0                94.0         109.0
# 10       14.0       9.2        0.92   15.0               102.0         117.0
# 11       14.0       9.5        1.06   13.0                86.0          99.0
# 0         NaN       NaN         NaN    NaN                 NaN           NaN
# 1         NaN       NaN         NaN    NaN                 NaN           NaN
# 2        13.0       8.8        1.00   13.0                 NaN           NaN
# 3        21.0       9.0        1.20   17.5                 NaN           NaN
# 4        22.0       8.5        1.40   15.7                 NaN           NaN
# 5        15.0       9.2        0.95   19.0                 NaN           NaN
# 6        12.0       9.1        1.13   11.0                72.0          83.0
# 7        17.0       9.7        1.24   14.0                64.0          74.0
# 8        12.0       9.0        1.01   12.0                82.0          94.0
# 9        14.0       9.7        1.11   13.0                73.0          84.0
#
#     bilirubin mg/dL  Testing
# 0               NaN   BYU SHC
# 1               NaN   BYU SHC
# 2               NaN   BYU SHC
# 3               NaN   BYU SHC
# 4               NaN   BYU SHC
# 5               NaN   BYU SHC
# 6              0.60   LabCorp
# 7              0.03   LabCorp
# 8              0.30   LabCorp
# 9              0.40   LabCorp
# 10             0.40   LabCorp
# 11             0.06   LabCorp
# 0               NaN   BYU SHC
# 1               NaN   BYU SHC
# 2               NaN   BYU SHC
# 3               NaN   BYU SHC
# 4               NaN   BYU SHC
# 5              0.20   LabCorp
# 6              0.05   LabCorp
# 7              0.07   LabCorp
# 8              0.70   LabCorp
# 9              0.60   LabCorp
#
# [22 rows x 29 columns]

# %% [markdown]
# The load_dataset function has various arguments that can be passed in. Two of these are the subjects to pull form the data frame and if you would like to redownload the data to fix any errors that might have arisen during initial download. Here are some examples of each of these parameters in action:

# %%
metab.load_dataset(redownload = True)
# Out:
#     subject       date  Na mmol/L  K mmol/L  Cl mmol/L  ECO2 mmol/L  \
# 0         1 2019-10-25        NaN       NaN        NaN          NaN
# 1         1 2019-11-22        NaN       NaN        NaN          NaN
# 2         1 2019-12-19      138.0       4.1      103.0         26.1
# 3         1 2020-01-31      140.0       3.7      104.0         26.2
# 4         1 2020-02-14      140.0       3.9      102.0         27.1
# 5         1 2020-02-21      139.0       3.8      102.0         26.4
# 6         1 2020-03-26      139.0       4.4      100.0         22.0
# 7         1 2020-06-29      141.0       4.0      103.0         21.0
# 8         1 2020-07-29      140.0       4.2      100.0         21.0
# 9         1 2020-09-17      140.0       4.2      102.0         25.0
# 10        1 2020-10-15      139.0       4.4      101.0         26.0
# 11        1 2020-11-12      137.0       4.3      100.0         25.0
# 0         2 2019-10-25        NaN       NaN        NaN          NaN
# 1         2 2019-11-22        NaN       NaN        NaN          NaN
# 2         2 2019-12-19      140.0       4.2      104.0         29.0
# 3         2 2020-01-31      142.0       4.0      105.0         27.9
# 4         2 2020-02-21      140.0       4.1      104.0         27.7
# 5         2 2020-06-29      139.0       4.3      102.0         23.0
# 6         2 2020-07-29      140.0       4.3       99.0         24.0
# 7         2 2020-09-17      143.0       4.8      102.0         26.0
# 8         2 2020-10-15      140.0       4.3      101.0         26.0
# 9         2 2020-11-12      140.0       4.6      100.0         29.0
#
#     AGAP mmol/L  AHDL mg/dL  VLDL mg/dL  LDL mg/dL  ...  A/G  GLUC mg/dL  \
# 0           NaN        43.0         NaN        NaN  ...  NaN          95
# 1           NaN        40.0         NaN        NaN  ...  NaN          94
# 2          13.0        42.0         NaN        NaN  ...  1.2          95
# 3          13.5        40.0         NaN        NaN  ...  1.3          95
# 4          14.8        42.0         NaN        NaN  ...  1.5          99
# 5          14.4        47.0         NaN        NaN  ...  1.4          97
# 6           NaN         NaN         NaN        NaN  ...  2.3          89
# 7           NaN        40.0        39.0      139.0  ...  2.4          85
# 8           NaN        42.0        58.0      120.0  ...  2.4          85
# 9           NaN        39.0        60.0      133.0  ...  2.4          90
# 10          NaN        38.0        53.0      120.0  ...  2.4          89
# 11          NaN        35.0        67.0      144.0  ...  2.2          88
# 0           NaN        34.0         NaN        NaN  ...  NaN         137
# 1           NaN        32.0         NaN        NaN  ...  NaN         105
# 2          11.2        36.0         NaN        NaN  ...  1.1         115
# 3          13.1        34.0         NaN        NaN  ...  1.2         113
# 4          12.4        32.0         NaN        NaN  ...  1.2         109
# 5           NaN        31.0        24.0      103.0  ...  2.0          92
# 6           NaN        27.0        36.0      136.0  ...  1.9          93
# 7           NaN        35.0        21.0      153.0  ...  2.2          73
# 8           NaN        32.0        25.0      142.0  ...  2.0         100
# 9           NaN        35.0        20.0      148.0  ...  1.9          79
#
#     BUN mg/dL  CA mg/dL  CRE2 mg/dL  BN/CR  eGFR NonAfrican Am  eGFR African  \
# 0         NaN       NaN         NaN    NaN                 NaN           NaN
# 1         NaN       NaN         NaN    NaN                 NaN           NaN
# 2        18.0       8.8        1.00   18.0                 NaN           NaN
# 3        14.0       8.6        1.00   14.0                 NaN           NaN
# 4        13.0       8.6        0.90   14.4                 NaN           NaN
# 5        16.0       8.8        0.90   17.8                 NaN           NaN
# 6        17.0      10.0        1.00   17.0                92.0           NaN
# 7        18.0       9.3        1.21   15.0                73.0          84.0
# 8        12.0       9.6        0.98   12.0                94.0         109.0
# 9        14.0       9.6        0.98   14.0                94.0         109.0
# 10       14.0       9.2        0.92   15.0               102.0         117.0
# 11       14.0       9.5        1.06   13.0                86.0          99.0
# 0         NaN       NaN         NaN    NaN                 NaN           NaN
# 1         NaN       NaN         NaN    NaN                 NaN           NaN
# 2        13.0       8.8        1.00   13.0                 NaN           NaN
# 3        21.0       9.0        1.20   17.5                 NaN           NaN
# 4        22.0       8.5        1.40   15.7                 NaN           NaN
# 5        15.0       9.2        0.95   19.0                 NaN           NaN
# 6        12.0       9.1        1.13   11.0                72.0          83.0
# 7        17.0       9.7        1.24   14.0                64.0          74.0
# 8        12.0       9.0        1.01   12.0                82.0          94.0
# 9        14.0       9.7        1.11   13.0                73.0          84.0
#
#     bilirubin mg/dL  Testing
# 0               NaN   BYU SHC
# 1               NaN   BYU SHC
# 2               NaN   BYU SHC
# 3               NaN   BYU SHC
# 4               NaN   BYU SHC
# 5               NaN   BYU SHC
# 6              0.60   LabCorp
# 7              0.03   LabCorp
# 8              0.30   LabCorp
# 9              0.40   LabCorp
# 10             0.40   LabCorp
# 11             0.06   LabCorp
# 0               NaN   BYU SHC
# 1               NaN   BYU SHC
# 2               NaN   BYU SHC
# 3               NaN   BYU SHC
# 4               NaN   BYU SHC
# 5              0.20   LabCorp
# 6              0.05   LabCorp
# 7              0.07   LabCorp
# 8              0.70   LabCorp
# 9              0.60   LabCorp
#
# [22 rows x 29 columns]

# %%
metab.load_dataset(subjects=[1])
# Out:
#     subject       date  Na mmol/L  K mmol/L  Cl mmol/L  ECO2 mmol/L  \
# 0         1 2019-10-25        NaN       NaN        NaN          NaN
# 1         1 2019-11-22        NaN       NaN        NaN          NaN
# 2         1 2019-12-19      138.0       4.1      103.0         26.1
# 3         1 2020-01-31      140.0       3.7      104.0         26.2
# 4         1 2020-02-14      140.0       3.9      102.0         27.1
# 5         1 2020-02-21      139.0       3.8      102.0         26.4
# 6         1 2020-03-26      139.0       4.4      100.0         22.0
# 7         1 2020-06-29      141.0       4.0      103.0         21.0
# 8         1 2020-07-29      140.0       4.2      100.0         21.0
# 9         1 2020-09-17      140.0       4.2      102.0         25.0
# 10        1 2020-10-15      139.0       4.4      101.0         26.0
# 11        1 2020-11-12      137.0       4.3      100.0         25.0
#
#     AGAP mmol/L  AHDL mg/dL  VLDL mg/dL  LDL mg/dL  ...  A/G  GLUC mg/dL  \
# 0           NaN        43.0         NaN        NaN  ...  NaN          95
# 1           NaN        40.0         NaN        NaN  ...  NaN          94
# 2          13.0        42.0         NaN        NaN  ...  1.2          95
# 3          13.5        40.0         NaN        NaN  ...  1.3          95
# 4          14.8        42.0         NaN        NaN  ...  1.5          99
# 5          14.4        47.0         NaN        NaN  ...  1.4          97
# 6           NaN         NaN         NaN        NaN  ...  2.3          89
# 7           NaN        40.0        39.0      139.0  ...  2.4          85
# 8           NaN        42.0        58.0      120.0  ...  2.4          85
# 9           NaN        39.0        60.0      133.0  ...  2.4          90
# 10          NaN        38.0        53.0      120.0  ...  2.4          89
# 11          NaN        35.0        67.0      144.0  ...  2.2          88
#
#     BUN mg/dL  CA mg/dL  CRE2 mg/dL  BN/CR  eGFR NonAfrican Am  eGFR African  \
# 0         NaN       NaN         NaN    NaN                 NaN           NaN
# 1         NaN       NaN         NaN    NaN                 NaN           NaN
# 2        18.0       8.8        1.00   18.0                 NaN           NaN
# 3        14.0       8.6        1.00   14.0                 NaN           NaN
# 4        13.0       8.6        0.90   14.4                 NaN           NaN
# 5        16.0       8.8        0.90   17.8                 NaN           NaN
# 6        17.0      10.0        1.00   17.0                92.0           NaN
# 7        18.0       9.3        1.21   15.0                73.0          84.0
# 8        12.0       9.6        0.98   12.0                94.0         109.0
# 9        14.0       9.6        0.98   14.0                94.0         109.0
# 10       14.0       9.2        0.92   15.0               102.0         117.0
# 11       14.0       9.5        1.06   13.0                86.0          99.0
#
#     bilirubin mg/dL  Testing
# 0               NaN   BYU SHC
# 1               NaN   BYU SHC
# 2               NaN   BYU SHC
# 3               NaN   BYU SHC
# 4               NaN   BYU SHC
# 5               NaN   BYU SHC
# 6              0.60   LabCorp
# 7              0.03   LabCorp
# 8              0.30   LabCorp
# 9              0.40   LabCorp
# 10             0.40   LabCorp
# 11             0.06   LabCorp
#
# [12 rows x 29 columns]

# %% [markdown]
# As you can see the redownload option takes a little longer to run as it is redownloading the data and the second data frame only shows data from subject 1 as requested. The default values to redownload and subjects is False and an empty list ([]), respectively.
#
# Load_dataset can also take in a version argument. The versioning scheme is specific to each data set with the dataset containing the most versions being the proteomic dataset. We will now use the proteomic dataset to show this next functionality. To see what the versions exist of a dataset you will need to call the following function after getting a dataset object:

# %%
prot = longitudinalCLL.get_proteomic()
prot.versions()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-c991bdd84364> in <module>
#       1 prot = longitudinalCLL.get_proteomic()
# ----> 2 prot.versions()
#
# ~\anaconda3\lib\site-packages\longitudinalCLL\dataset.py in versions(self, file_path)
#     114     def versions(self, file_path = ""):
#     115         index_path = self.path_here + file_path + "\index_table.tsv"
# --> 116         if path.exists(self.index_path):
#     117             table = pd.read_csv(index_path, sep='\t', header=0, index_col='key')
#     118             return table['key']
#
# AttributeError: 'Proteomic' object has no attribute 'index_path'

# %% [markdown]
# Here it lists all of the possible datasets that you can download. By default load_dataset will load the most current version of each dataset. To specify what version of the dataset you would like to download you would call the load_dataset function like so:

# %%
prot.load_dataset(version = "July_noMBR_FP")
