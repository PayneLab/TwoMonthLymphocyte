# %% [markdown]
# # Comparisons
#
# In this notebook we analyze the proteins in the Johnston, Thurgood, and Mayer papers. First, we extract their total and differential proteins. We also sort the differential proteins into those that are upregulated and those that are downregulated. After we extract their data, we make a venn diagram comparing their differential proteins, and another venn diagram comparing their total proteins. We then do a pathway enrichment on the differential proteins. Finally, we make a venn diagram comparing the total proteins in each paper to the total proteins we found.

# %%
johnston_file = "data/134638_0_supp_38937_p0y7zb.xlsx"
mayer_file = "data/133399_0_supp_15943_4ybsvb.xlsx"
thurgood_file = "data/bjh15751-sup-0006-TableS3.xlsx"

# %% [markdown]
# ## Mayer Paper
#
# Dowload and import supplementary table 3, use after imputation sheets (Mayer et al., 2018)
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5795392/bin/supp_RA117.000425_133399_0_supp_15943_4ybsvb.xlsx
#
# I parse the dataframe and extract all the names of identified proteins, all the proteins labeled as significantly upregulated (+ in t-test difference) and downregulated (- in t-test difference), and differential (+ in t-test).
# The differential and total proteins identified will be used to generate venn diagrams.
# The upregulated and downregulated will be used to generate a functional pathay analysis.
# In the paper they found 440 upregulated and 427 downregulated, however, these numbers double-count some proteins. This analysis finds 425 upregulated and 376 downregulated, none are double-counted in this analysis. There are 6, 945 total proteins identified in the paper.

# %%
import pandas as pd
import requests
import os.path
import os
from os import path
import matplotlib.pyplot as plt
from matplotlib_venn import venn2
from matplotlib_venn import venn3

# %% [markdown]
# Since this paper differentiated between nuclear and cytoplasmic, we have to read in 2 files. First, we pull the nuclear file and extract the significant, upregulated, and downregulated proteins.

# %%
ne_sheet_name = "NE_after imputation"
#The other is "NE_before imputation"
m_ne_df = pd.read_excel(mayer_file, sheet_name = ne_sheet_name)

# %%
m_sig_ne = m_ne_df.loc[m_ne_df['Student\'s t-test Significant CLL vs elderly Bcells'] == '+']
m_up_ne = m_sig_ne.loc[m_sig_ne['Student\'s t-test Difference  CLL vs  elderly B cells'] > 0]
m_down_ne = m_sig_ne.loc[m_sig_ne['Student\'s t-test Difference  CLL vs  elderly B cells'] < 0]

# %% [markdown]
# Next, we pull the cytoplasmic file and extract the significant, upregulated, and downregulated proteins.

# %%
mayer_cyt_sheet_name = "CYT_after imputation"
m_cyt_df = pd.read_excel(mayer_file, sheet_name= mayer_cyt_sheet_name,
                         skiprows = 1) #There is a header saying sup. table s3

# %%
m_sig_cyt = m_cyt_df.loc[m_cyt_df['Student\'s t-test Significant CLL vs elderly B cells'] == '+']
m_up_cyt = m_sig_cyt.loc[m_sig_cyt['Student\'s t-test Difference  CLL vs  elderly B cells'] > 0]
m_down_cyt = m_sig_cyt.loc[m_sig_cyt['Student\'s t-test Difference  CLL vs  elderly B cells'] < 0]

# %%
m_diff = []

# %%
sig_frames = [m_sig_ne, m_sig_cyt]
sig = pd.concat(sig_frames)

# %%
for protein in sig['Protein IDs'] :
    temp = protein.split(";")
    m_diff.append(temp[0])

# %%
m_upreg = []

# %%
up_frames = [m_up_ne, m_up_cyt]
m_u = pd.concat(up_frames)

# %%
for protein in m_u['Protein IDs'] :
    temp = protein.split(";")
    m_upreg.append(temp[0])

# %%
m_downreg = []

# %%
down_frames = [m_down_ne, m_down_cyt]
m_d = pd.concat(down_frames)

# %%
for protein in m_d['Protein IDs'] :
    temp = protein.split(";")
    m_downreg.append(temp[0])

# %% [markdown]
# The following cells extract all the proteins identified

# %%
m_tot = []

# %%
frames = [m_ne_df, m_cyt_df]
m_t = pd.concat(frames)

# %%
m_t.dropna(subset = ['Protein IDs'], inplace = True)

# %%
for protein in m_t['Protein IDs']:
    temp = protein.split(";")
    m_tot.append(temp[0])

# %% [markdown]
# Save to a file

# %%
#m_diff.to_csv('data/m_diff.csv')
#m_tot.to_csv('data/m_tot.csv')

# %% [markdown]
# ## Thurgood Paper
# Download and import supplementary table 3 (Thurgood et al., 2019)
# https://onlinelibrary.wiley.com/action/downloadSupplement?doi=10.1111%2Fbjh.15751&file=bjh15751-sup-0006-TableS3.xlsx
#
# I parse the dataframe and extract all the proteins labeled as significantly upregulated (+) and downregulated (-) and differential. There was no list with all the identified proteins
# The differential proteins will be used to generate venn diagrams.
# The upregulated and downregulated will be used to generate a functional pathay analysis.
# In the paper they found 255 upregulated and 94 downregulated. This analysis finds 257 upregulated and 94 downregulated.

# %%
thur_sheet_name = "Total list of proteins"
t_df = pd.read_excel(thurgood_file, sheet_name = thur_sheet_name)

# %% [markdown]
# Here I am extracting all the proteins from the file containing differential proteins. I also sort into upregulated and downregulated.

# %%
t_upreg = []

# %%
t_u = t_df.loc[t_df['CLL vs. NOR_log2_sfc'] > 0]

# %%
for protein in t_u['protein']:
    temp = protein.split("|")
    protein_name = temp[1].split("-")[0]
    t_upreg.append(protein_name)

# %%
t_downreg = []

# %%
t_d = t_df.loc[t_df['CLL vs. NOR_log2_sfc'] < 0]

# %%
for protein in t_d['protein']:
    temp = protein.split("|")
    protein_name = temp[1].split("-")[0]
    t_downreg.append(protein_name)

# %%
t_diff = []

# %%
t_d = t_df['protein']

# %%
for protein in t_d:
    temp = protein.split("|")
    protein_name = temp[1].split("-")[0]
    t_diff.append(protein_name)

# %% [markdown]
# Save to a file

# %%
#t_diff.to_csv('data/t_diff.csv')

# %% [markdown]
# ## Johnston Paper
# Download and import supplementary table 2 (Johnston et al., 2018)
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5880099/bin/supp_RA117.000539_134638_0_supp_38937_p0y7zb.xlsx
#
# I parse the dataframe and extract all the names of identified proteins, all the proteins labeled as significantly upregulated (>0.3) and downregulated (<-0.3), and differential.
# The differential and total proteins identified will be used to generate venn diagrams.
# The upregulated and downregulated will be used to generate a functional pathay analysis.
# In the paper they found 544 upregulated and 592 downregulated. This analysis finds 545 upregulated and 592 downregulated.

# %%
j_sheet_name = "CLL proteome"
j_df = pd.read_excel(johnston_file, sheet_name = j_sheet_name)

# %% [markdown]
# Here I extract all the proteins with a differential regulation score (>0.3 and <-0.3). I sort them into upregulated and downregulated as well as add them to the differential. I also extract the names of all proteins identified.

# %%
j_u = j_df.loc[j_df['Regulation score'] >= 0.3]
j_upreg = j_u['Protein group accession']

# %%
j_d = j_df.loc[j_df['Regulation score'] <= -0.3]
j_downreg = j_d['Protein group accession']

# %%
diff_frames = [j_downreg, j_upreg]
j_diff = pd.concat(diff_frames)

# %%
j_tot = j_df['Protein group accession']

# %% [markdown]
# Save to a file

# %%
#j_diff.to_csv('data/j_diff.csv')
#j_tot.to_csv('data/j_tot.csv')

# %% [markdown]
# ## Overlap

# %% [markdown]
# Here I make venn diagrams looking at the overlaps between the papers

# %%
import matplotlib.pyplot as plt
from matplotlib_venn import venn2
from matplotlib_venn import venn3

# %%
venn3(subsets = (set(m_diff), set(t_diff), set(j_diff)), set_labels = ('Mayer', 'Thurgood', 'Johnston'))
#plt.savefig('data/diff_overlap.png')
plt.show()
# Johnston 1 off (912)

# %% [markdown]
# This venn diagram shows the overlap between the differential proteins of each paper

# %%
venn2(subsets = (set(m_diff), set(j_diff)), set_labels = ('Mayer', 'Johnston'))
#plt.savefig('data/diff_overlap_2.png')
plt.show()

# %% [markdown]
# This is a little messier, but -

# %%
m_and_j = set(m_tot).intersection(set(j_tot))
mj_m_diff = m_and_j.intersection(m_diff)
mj_j_diff = m_and_j.intersection(j_diff)

# %%
venn3(subsets = (set(m_diff), set(j_diff), m_and_j), set_labels = ('Mayer', 'Johnston',
                                                                   'Present in both totals'))
#plt.savefig('data/diff_overlap_3.png')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
venn2(subsets = (set(mj_m_diff), set(mj_j_diff)), set_labels = ('Mayer', 'Johnston'))
#plt.savefig('data/diff_overlap_4.png')
plt.show()

# %%
venn2(subsets = (set(m_upreg), set(j_upreg)), set_labels = ('Mayer up', 'Johnston up'))
#plt.savefig('data/diff_overlap_2.png')
plt.show()

# %%
venn2(subsets = (set(m_downreg), set(j_downreg)), set_labels = ('Mayer down', 'Johnston down'))
#plt.savefig('data/diff_overlap_2.png')
plt.show()

# %% [markdown]
# I got curious if they were agreeing on whether those differential proteins were up or down regulated, so I decided to venn those subsets.

# %%
data_lists = {
    'Mayer down': pd.Series(m_downreg),
    'Mayer up': pd.Series(m_upreg),
    'Johnston down': pd.Series(j_downreg),
    'Johnston up':pd.Series(j_upreg)
}

# %%
index = set(m_downreg).union(set(m_upreg), set(j_downreg), set(j_upreg))
net_data = pd.DataFrame(index=index, columns=['Mayer down', 'Mayer up', 'Johnston down', 'Johnston up'])

for column in net_data:
    for prot in net_data.index:
        if prot in data_lists[column].values:
            net_data[column][prot] = True
        else: net_data[column][prot] = False
net_data.head()
# Out:
#        Mayer down Mayer up Johnston down Johnston up
# Q6NVY1      False    False         False        True
# Q9H8H3      False     True         False       False
# Q9H3R0      False    False          True       False
# P42765      False     True         False       False
# A0MZ66      False    False          True       False

# %%
print(net_data.apply(sum))
# Out:
# Mayer down       371
# Mayer up         425
# Johnston down    592
# Johnston up      545
# dtype: int64

# %%
import venn
from numpy import nan
set_cols = {}
for col in net_data:
    set_cols[col] = set(net_data[col].replace(False, nan).dropna().index)


labels = venn.get_labels(set_cols.values(), fill=['number'])
fig, ax = venn.venn4(labels, names=['Mayer down', 'Mayer up', 'Johnston down', 'Johnston up'])
#plt.savefig('data/up-down-over.png')
plt.show()
# Out:
# C:\Users\carol\anaconda3\lib\site-packages\venn\_backwards_compatibility.py:15: UserWarning: `get_labels()` is retained for backwards compatibility; use `generate_petal_labels()` or the higher level `venn()` instead
#   warn((
# C:\Users\carol\anaconda3\lib\site-packages\venn\_backwards_compatibility.py:30: UserWarning: `venn4()` is retained for backwards compatibility; use `venn()` instead
#   warn((

# %% [markdown]
# This venn diagram shows the overlap between differential proteins of Mayer and Johnston

# %%
venn2(subsets = (set(m_tot), set(j_tot)), set_labels = ('Mayer', 'Johnston'))
#plt.savefig('data/total_overlap.png')
plt.show()

# %% [markdown]
# This venn diagram shows the overlap for the total proteins in Johnston and Mayer. Thurgood doesn't have a list of total proteins

# %% [markdown]
# ## Pathway Analysis

# %% [markdown]
# Here I am doing a functional pathway enrichment. I import GProfiler and run a KEGG analysis on the significantly upregulated and downregulated proteins for each paper.

# %%
from gprofiler import GProfiler

# %%
gp = GProfiler(return_dataframe = True)

# %%
johnston_upregulated_gp = gp.profile(organism='hsapiens', query=list(j_upreg))
johnston_upregulated_gp[johnston_upregulated_gp["source"] == "KEGG"]
# Out:
#      source      native                                        name  \
# 136    KEGG  KEGG:03040                                 Spliceosome
# 535    KEGG  KEGG:03015                   mRNA surveillance pathway
# 544    KEGG  KEGG:00280  Valine, leucine and isoleucine degradation
# 1058   KEGG  KEGG:03420                  Nucleotide excision repair
# 1060   KEGG  KEGG:04330                     Notch signaling pathway
#
#            p_value  significant                                 description  \
# 136   2.851014e-22         True                                 Spliceosome
# 535   5.066431e-08         True                   mRNA surveillance pathway
# 544   8.914372e-08         True  Valine, leucine and isoleucine degradation
# 1058  3.496473e-02         True                  Nucleotide excision repair
# 1060  3.512498e-02         True                     Notch signaling pathway
#
#       term_size  query_size  intersection_size  effective_domain_size  \
# 136         150         240                 37                   8000
# 535          98         240                 18                   8000
# 544          48         240                 13                   8000
# 1058         45         240                  7                   8000
# 1060         59         240                  8                   8000
#
#       precision    recall    query       parents
# 136    0.154167  0.246667  query_1  [KEGG:00000]
# 535    0.075000  0.183673  query_1  [KEGG:00000]
# 544    0.054167  0.270833  query_1  [KEGG:00000]
# 1058   0.029167  0.155556  query_1  [KEGG:00000]
# 1060   0.033333  0.135593  query_1  [KEGG:00000]

# %%
johnston_downregulated_gp = gp.profile(organism='hsapiens', query=list(j_downreg))
johnston_downregulated_gp[johnston_downregulated_gp["source"] == "KEGG"]
# Out:
#     source      native                                    name   p_value  \
# 168   KEGG  KEGG:04670    Leukocyte transendothelial migration  0.000014
# 210   KEGG  KEGG:04142                                Lysosome  0.000083
# 256   KEGG  KEGG:04062             Chemokine signaling pathway  0.000551
# 321   KEGG  KEGG:04015                  Rap1 signaling pathway  0.002607
# 350   KEGG  KEGG:04611                     Platelet activation  0.004443
# 358   KEGG  KEGG:04070   Phosphatidylinositol signaling system  0.004946
# 398   KEGG  KEGG:05417               Lipid and atherosclerosis  0.010659
# 409   KEGG  KEGG:05135                      Yersinia infection  0.012997
# 411   KEGG  KEGG:04662       B cell receptor signaling pathway  0.013457
# 475   KEGG  KEGG:05140                           Leishmaniasis  0.027925
# 482   KEGG  KEGG:05146                              Amoebiasis  0.031130
# 483   KEGG  KEGG:00562           Inositol phosphate metabolism  0.031337
# 493   KEGG  KEGG:04144                             Endocytosis  0.035849
# 518   KEGG  KEGG:04970                      Salivary secretion  0.047855
# 521   KEGG  KEGG:00513  Various types of N-glycan biosynthesis  0.048984
#
#      significant                             description  term_size  \
# 168         True    Leukocyte transendothelial migration        114
# 210         True                                Lysosome        128
# 256         True             Chemokine signaling pathway        190
# 321         True                  Rap1 signaling pathway        210
# 350         True                     Platelet activation        124
# 358         True   Phosphatidylinositol signaling system         97
# 398         True               Lipid and atherosclerosis        214
# 409         True                      Yersinia infection        136
# 411         True       B cell receptor signaling pathway         79
# 475         True                           Leishmaniasis         72
# 482         True                              Amoebiasis        101
# 483         True           Inositol phosphate metabolism         73
# 493         True                             Endocytosis        252
# 518         True                      Salivary secretion         91
# 521         True  Various types of N-glycan biosynthesis         39
#
#      query_size  intersection_size  effective_domain_size  precision  \
# 168         291                 18                   8000   0.061856
# 210         291                 18                   8000   0.061856
# 256         291                 21                   8000   0.072165
# 321         291                 21                   8000   0.072165
# 350         291                 15                   8000   0.051546
# 358         291                 13                   8000   0.044674
# 398         291                 20                   8000   0.068729
# 409         291                 15                   8000   0.051546
# 411         291                 11                   8000   0.037801
# 475         291                 10                   8000   0.034364
# 482         291                 12                   8000   0.041237
# 483         291                 10                   8000   0.034364
# 493         291                 21                   8000   0.072165
# 518         291                 11                   8000   0.037801
# 521         291                  7                   8000   0.024055
#
#        recall    query       parents
# 168  0.157895  query_1  [KEGG:00000]
# 210  0.140625  query_1  [KEGG:00000]
# 256  0.110526  query_1  [KEGG:00000]
# 321  0.100000  query_1  [KEGG:00000]
# 350  0.120968  query_1  [KEGG:00000]
# 358  0.134021  query_1  [KEGG:00000]
# 398  0.093458  query_1  [KEGG:00000]
# 409  0.110294  query_1  [KEGG:00000]
# 411  0.139241  query_1  [KEGG:00000]
# 475  0.138889  query_1  [KEGG:00000]
# 482  0.118812  query_1  [KEGG:00000]
# 483  0.136986  query_1  [KEGG:00000]
# 493  0.083333  query_1  [KEGG:00000]
# 518  0.120879  query_1  [KEGG:00000]
# 521  0.179487  query_1  [KEGG:00000]

# %%
thurgood_upregulated_gp = gp.profile(organism='hsapiens', query=list(t_upreg))
thurgood_upregulated_gp[thurgood_upregulated_gp["source"] == "KEGG"]
# Out:
#     source      native                            name       p_value  \
# 152   KEGG  KEGG:03040                     Spliceosome  3.967121e-10
# 489   KEGG  KEGG:03010                        Ribosome  5.374000e-04
# 495   KEGG  KEGG:05171  Coronavirus disease - COVID-19  6.298390e-04
# 510   KEGG  KEGG:01200               Carbon metabolism  1.022006e-03
# 533   KEGG  KEGG:00020       Citrate cycle (TCA cycle)  1.583167e-03
# 671   KEGG  KEGG:03050                      Proteasome  1.947318e-02
# 735   KEGG  KEGG:03015       mRNA surveillance pathway  4.746521e-02
#
#      significant                     description  term_size  query_size  \
# 152         True                     Spliceosome        150         151
# 489         True                        Ribosome        153         151
# 495         True  Coronavirus disease - COVID-19        231         151
# 510         True               Carbon metabolism        116         151
# 533         True       Citrate cycle (TCA cycle)         30         151
# 671         True                      Proteasome         46         151
# 735         True       mRNA surveillance pathway         98         151
#
#      intersection_size  effective_domain_size  precision    recall    query  \
# 152                 20                   8000   0.132450  0.133333  query_1
# 489                 13                   8000   0.086093  0.084967  query_1
# 495                 16                   8000   0.105960  0.069264  query_1
# 510                 11                   8000   0.072848  0.094828  query_1
# 533                  6                   8000   0.039735  0.200000  query_1
# 671                  6                   8000   0.039735  0.130435  query_1
# 735                  8                   8000   0.052980  0.081633  query_1
#
#           parents
# 152  [KEGG:00000]
# 489  [KEGG:00000]
# 495  [KEGG:00000]
# 510  [KEGG:00000]
# 533  [KEGG:00000]
# 671  [KEGG:00000]
# 735  [KEGG:00000]

# %%
thurgood_downregulated_gp = gp.profile(organism='hsapiens', query=list(t_downreg))
thurgood_downregulated_gp[thurgood_downregulated_gp["source"] == "KEGG"]
# Out:
# Empty DataFrame
# Columns: [source, native, name, p_value, significant, description, term_size, query_size, intersection_size, effective_domain_size, precision, recall, query, parents]
# Index: []

# %%
mayer_upregulated_gp = gp.profile(organism='hsapiens', query=list(m_upreg))
mayer_upregulated_gp[mayer_upregulated_gp["source"] == "KEGG"]
# Out:
#     source      native                                     name   p_value  \
# 479   KEGG  KEGG:00620                      Pyruvate metabolism  0.002048
# 516   KEGG  KEGG:01100                       Metabolic pathways  0.005310
# 545   KEGG  KEGG:00630  Glyoxylate and dicarboxylate metabolism  0.008932
#
#      significant                              description  term_size  \
# 479         True                      Pyruvate metabolism         47
# 516         True                       Metabolic pathways       1491
# 545         True  Glyoxylate and dicarboxylate metabolism         30
#
#      query_size  intersection_size  effective_domain_size  precision  \
# 479         204                  8                   8000   0.039216
# 516         204                 61                   8000   0.299020
# 545         204                  6                   8000   0.029412
#
#        recall    query       parents
# 479  0.170213  query_1  [KEGG:00000]
# 516  0.040912  query_1  [KEGG:00000]
# 545  0.200000  query_1  [KEGG:00000]

# %%
mayer_downregulated_gp = gp.profile(organism='hsapiens', query=list(m_downreg))
mayer_downregulated_gp[mayer_downregulated_gp["source"] == "KEGG"]
# Out:
#     source      native                                             name  \
# 34    KEGG  KEGG:04610              Complement and coagulation cascades
# 44    KEGG  KEGG:04640                       Hematopoietic cell lineage
# 78    KEGG  KEGG:04512                         ECM-receptor interaction
# 91    KEGG  KEGG:04611                              Platelet activation
# 109   KEGG  KEGG:04613          Neutrophil extracellular trap formation
# 158   KEGG  KEGG:04145                                        Phagosome
# 204   KEGG  KEGG:04810                 Regulation of actin cytoskeleton
# 247   KEGG  KEGG:04510                                   Focal adhesion
# 274   KEGG  KEGG:05140                                    Leishmaniasis
# 286   KEGG  KEGG:04670             Leukocyte transendothelial migration
# 310   KEGG  KEGG:05144                                          Malaria
# 330   KEGG  KEGG:05150                  Staphylococcus aureus infection
# 371   KEGG  KEGG:05414                           Dilated cardiomyopathy
# 376   KEGG  KEGG:05412  Arrhythmogenic right ventricular cardiomyopathy
#
#           p_value  significant  \
# 34   3.480036e-13         True
# 44   4.740364e-10         True
# 78   1.456775e-07         True
# 91   3.699831e-07         True
# 109  1.455110e-06         True
# 158  2.947435e-05         True
# 204  2.810250e-04         True
# 247  1.718691e-03         True
# 274  4.191412e-03         True
# 286  6.897581e-03         True
# 310  1.290488e-02         True
# 330  1.865890e-02         True
# 371  3.637958e-02         True
# 376  4.126518e-02         True
#
#                                          description  term_size  query_size  \
# 34               Complement and coagulation cascades         85         188
# 44                        Hematopoietic cell lineage         95         188
# 78                          ECM-receptor interaction         88         188
# 91                               Platelet activation        124         188
# 109          Neutrophil extracellular trap formation        189         188
# 158                                        Phagosome        147         188
# 204                 Regulation of actin cytoskeleton        216         188
# 247                                   Focal adhesion        200         188
# 274                                    Leishmaniasis         72         188
# 286             Leukocyte transendothelial migration        114         188
# 310                                          Malaria         49         188
# 330                  Staphylococcus aureus infection         87         188
# 371                           Dilated cardiomyopathy         95         188
# 376  Arrhythmogenic right ventricular cardiomyopathy         77         188
#
#      intersection_size  effective_domain_size  precision    recall    query  \
# 34                  20                   8000   0.106383  0.235294  query_1
# 44                  18                   8000   0.095745  0.189474  query_1
# 78                  15                   8000   0.079787  0.170455  query_1
# 91                  17                   8000   0.090426  0.137097  query_1
# 109                 20                   8000   0.106383  0.105820  query_1
# 158                 16                   8000   0.085106  0.108844  query_1
# 204                 18                   8000   0.095745  0.083333  query_1
# 247                 16                   8000   0.085106  0.080000  query_1
# 274                  9                   8000   0.047872  0.125000  query_1
# 286                 11                   8000   0.058511  0.096491  query_1
# 310                  7                   8000   0.037234  0.142857  query_1
# 330                  9                   8000   0.047872  0.103448  query_1
# 371                  9                   8000   0.047872  0.094737  query_1
# 376                  8                   8000   0.042553  0.103896  query_1
#
#           parents
# 34   [KEGG:00000]
# 44   [KEGG:00000]
# 78   [KEGG:00000]
# 91   [KEGG:00000]
# 109  [KEGG:00000]
# 158  [KEGG:00000]
# 204  [KEGG:00000]
# 247  [KEGG:00000]
# 274  [KEGG:00000]
# 286  [KEGG:00000]
# 310  [KEGG:00000]
# 330  [KEGG:00000]
# 371  [KEGG:00000]
# 376  [KEGG:00000]

# %% [markdown]
# # Overlap with our paper

# %% [markdown]
# First I import and load our data as port

# %%
import longitudinalCLL

# %%
prot = longitudinalCLL.get_proteomic()

prot.load_dataset(version='July_noMBR_FP', subjects = [])
# Out:
#             Subject1_B_cells_062920_C_10  Subject1_B_cells_062920_C_11  \
# Protein ID
# A0A0B4J2D5                     3203277.5                     4697996.0
# A0AVT1                         1917388.2                     3033529.2
# A0FGR8                               0.0                           0.0
# A6NHR9                         2650513.5                           0.0
# A8K2U0                               0.0                           0.0
# ...                                  ...                           ...
# O15068                               0.0                           0.0
# Q14C86                               0.0                           0.0
# Q8N4T8                               0.0                           0.0
# Q8IW45                               0.0                           0.0
# Q96PP8                               0.0                           0.0
#
#             Subject1_B_cells_062920_C_12  Subject1_B_cells_062920_C_13  \
# Protein ID
# A0A0B4J2D5                     7346776.5                     8472867.0
# A0AVT1                         3773018.8                     1865758.6
# A0FGR8                               0.0                           0.0
# A6NHR9                         3788095.8                           0.0
# A8K2U0                               0.0                     1149867.8
# ...                                  ...                           ...
# O15068                               0.0                           0.0
# Q14C86                         1139333.0                           0.0
# Q8N4T8                               0.0                           0.0
# Q8IW45                               0.0                           0.0
# Q96PP8                               0.0                           0.0
#
#             Subject1_B_cells_062920_C_9  Subject1_B_cells_072920_C_4  \
# Protein ID
# A0A0B4J2D5                    4280919.5                          0.0
# A0AVT1                        5191332.5                    3332031.5
# A0FGR8                              0.0                          0.0
# A6NHR9                              0.0                    1845555.5
# A8K2U0                              0.0                          0.0
# ...                                 ...                          ...
# O15068                              0.0                          0.0
# Q14C86                              0.0                          0.0
# Q8N4T8                              0.0                          0.0
# Q8IW45                              0.0                          0.0
# Q96PP8                              0.0                          0.0
#
#             Subject1_B_cells_072920_C_5  Subject1_B_cells_072920_C_6  \
# Protein ID
# A0A0B4J2D5                   4787781.50                    2153860.2
# A0AVT1                       2464089.00                    2290868.2
# A0FGR8                             0.00                          0.0
# A6NHR9                        933499.44                    1958162.5
# A8K2U0                             0.00                          0.0
# ...                                 ...                          ...
# O15068                             0.00                          0.0
# Q14C86                             0.00                     994677.5
# Q8N4T8                             0.00                          0.0
# Q8IW45                             0.00                          0.0
# Q96PP8                             0.00                          0.0
#
#             Subject1_B_cells_072920_C_8  Subject1_B_cells_072920_C_9  ...  \
# Protein ID                                                            ...
# A0A0B4J2D5                    5444238.5                   5514300.50  ...
# A0AVT1                        2486001.2                   2596365.20  ...
# A0FGR8                              0.0                         0.00  ...
# A6NHR9                        1604476.4                    418360.38  ...
# A8K2U0                        2272656.2                         0.00  ...
# ...                                 ...                          ...  ...
# O15068                              0.0                         0.00  ...
# Q14C86                              0.0                    632145.70  ...
# Q8N4T8                              0.0                         0.00  ...
# Q8IW45                              0.0                         0.00  ...
# Q96PP8                              0.0                         0.00  ...
#
#             Subject2_T_cells_062920_F_12  Subject2_T_cells_062920_F_13  \
# Protein ID
# A0A0B4J2D5                           0.0                    4905873.00
# A0AVT1                         1091121.4                     630647.25
# A0FGR8                         1514363.4                     866311.94
# A6NHR9                               0.0                          0.00
# A8K2U0                               0.0                          0.00
# ...                                  ...                           ...
# O15068                               0.0                          0.00
# Q14C86                               0.0                          0.00
# Q8N4T8                               0.0                          0.00
# Q8IW45                               0.0                          0.00
# Q96PP8                         2672994.5                          0.00
#
#             Subject2_T_cells_062920_F_14  Subject2_T_cells_062920_F_9  \
# Protein ID
# A0A0B4J2D5                           0.0                    3405266.0
# A0AVT1                          576871.9                          0.0
# A0FGR8                               0.0                          0.0
# A6NHR9                               0.0                          0.0
# A8K2U0                               0.0                          0.0
# ...                                  ...                          ...
# O15068                               0.0                          0.0
# Q14C86                               0.0                          0.0
# Q8N4T8                               0.0                          0.0
# Q8IW45                               0.0                          0.0
# Q96PP8                         1829618.0                          0.0
#
#             Subject2_T_cells_072920_F_1  Subject2_T_cells_072920_F_3  \
# Protein ID
# A0A0B4J2D5                   4656720.00                    1673629.9
# A0AVT1                             0.00                          0.0
# A0FGR8                             0.00                          0.0
# A6NHR9                        430484.97                          0.0
# A8K2U0                             0.00                          0.0
# ...                                 ...                          ...
# O15068                             0.00                          0.0
# Q14C86                             0.00                          0.0
# Q8N4T8                             0.00                          0.0
# Q8IW45                             0.00                          0.0
# Q96PP8                             0.00                          0.0
#
#             Subject2_T_cells_072920_F_4  Subject2_T_cells_072920_F_5  \
# Protein ID
# A0A0B4J2D5                    6060600.5                    2407679.5
# A0AVT1                              0.0                     827356.1
# A0FGR8                              0.0                          0.0
# A6NHR9                              0.0                          0.0
# A8K2U0                              0.0                          0.0
# ...                                 ...                          ...
# O15068                              0.0                          0.0
# Q14C86                              0.0                          0.0
# Q8N4T8                              0.0                          0.0
# Q8IW45                              0.0                          0.0
# Q96PP8                              0.0                          0.0
#
#             Subject2_T_cells_072920_F_6  Subject2_T_cells_072920_F_8
# Protein ID
# A0A0B4J2D5                    7791855.0                   5542659.50
# A0AVT1                        1260652.0                         0.00
# A0FGR8                         653698.6                    879074.56
# A6NHR9                         538303.6                    948190.40
# A8K2U0                              0.0                         0.00
# ...                                 ...                          ...
# O15068                              0.0                         0.00
# Q14C86                        1029046.4                         0.00
# Q8N4T8                              0.0                         0.00
# Q8IW45                              0.0                         0.00
# Q96PP8                              0.0                         0.00
#
# [2426 rows x 43 columns]

# %% [markdown]
# Now I make the data into a dataframe so I can compare it to the other papers

# %%
payne_df = prot.data_frame.reset_index()

# %%
venn3(subsets = (set(m_tot), set(j_tot), set(payne_df['Protein ID'])), set_labels = ('Mayer', 'Johnston', 'Payne'))
#plt.savefig('data/our_overlap.png')
plt.show()

# %%
venn3(subsets = (set(m_diff), set(j_diff), set(payne_df['Protein ID'])), set_labels = ('Mayer Differential', 'Johnston Differential', 'Payne Total'))
#plt.savefig('data/differential_overlap_payne.png')
plt.show()

# %% [markdown]
# ### Scratch tests

# %% [markdown]
# Now I am checking Mayer

# %%
venn2(subsets = (set(m_tot), set(m_diff)), set_labels = ('Total', 'Differential'))
plt.show()

# %% [markdown]
# And Johnston

# %%
venn2(subsets = (set(j_tot), set(j_diff)), set_labels = ('Total', 'Differential'))
plt.show()

# %%
j_p = j_df[['Protein group accession', "-Log10(p value)"]]
j_p.set_index('Protein group accession')
# Out:
#                          -Log10(p value)
# Protein group accession
# Q07065                          7.749376
# Q9NQY0                          7.778704
# P01833                          4.903921
# Q6K0P9                          6.030706
# O94921                          7.838829
# ...                                  ...
# Q16799                          5.895298
# A2RUS2                          8.119950
# Q12797                          7.515437
# Q6ZRY4                          7.789193
# O60229                          7.515437
#
# [5956 rows x 1 columns]

# %%
len(m_and_j)
# Out:
# 5328

# %%
#mayer_all = pd.concat([m_ne_df, m_cyt_df])
#mayer_p_1 = m_cyt_df[['Protein IDs', "Student's t-test p-value CLL vs  elderly B cells"]] #ADDED
mayer_p = m_ne_df[['Protein IDs', "Student's t-test p-value CLL vs  elderly B cells"]]
#mayer_p = pd.concat([mayer_p_1, mayer_p])
#mayer_p = mayer_p.drop_duplicates()
mayer_p.set_index('Protein IDs')
# Out:
#                Student's t-test p-value CLL vs  elderly B cells
# Protein IDs
# A0AV96                                                 0.174310
# A0AVT1                                                 0.353243
# A0FGR8                                                 0.047417
# A0JLT2                                                 0.217343
# A0JNW5                                                 0.566918
# ...                                                         ...
# Q9Y6X5                                                 0.964055
# Q9Y6X8;Q9H4I2                                          0.767589
# Q9Y6X9                                                 0.929746
# Q9Y6Y0                                                 0.952956
# Q9Y6Y8                                                 0.815942
#
# [6535 rows x 1 columns]

# %%
mj_intersection = set(mayer_p['Protein IDs']).intersection(set(j_p['Protein group accession']))
#mj_intersection = set(j_p.index).intersection(set(mayer_p.index))

# %%
len(mj_intersection)
# Out:
# 4901

# %%
#This may be because of the combination thing 
#    - p1;p2 vs p2;p3 won't count p2, 
#    but we can deal with that later if it's important enough

# %%
from numpy import log10

df_mj_pvals = pd.DataFrame(index = list(mj_intersection), columns = 
                           ['Mayer et al. -log10(p)', 'Johnston et al. -log10(p)'])
#df_mj_pvals['Mayer et al. -log10(p)'] = mayer_p["Student's t-test p-value CLL vs elderly B cells"]
#df_mj_pvals['Johnston et al. -log10(p)'] = j_p["-Log10(p value)"]

# %%
for i in mj_intersection:
    val = float(mayer_p[mayer_p['Protein IDs']==i]["Student's t-test p-value CLL vs  elderly B cells"])
    df_mj_pvals.loc[i, 'Mayer et al. -log10(p)'] = -log10(val)#since this is p and the other is -log(p)
    
    valj = float(j_p[j_p['Protein group accession']==i]["-Log10(p value)"])
    df_mj_pvals.loc[i,'Johnston et al. -log10(p)'] = valj

# %%
df_mj_pvals
# Out:
#        Mayer et al. -log10(p) Johnston et al. -log10(p)
# Q6NVY1               0.713492                   3.39857
# Q9UBE0                1.06456                   3.47315
# Q9H8H3                2.03951                   1.90002
# P42765                  3.444                   3.17895
# O15047                1.56054                  0.965006
# ...                       ...                       ...
# O75695              0.0565243                    4.2936
# Q8N954              0.0236023                   1.28711
# Q6IEG0                0.83532                   4.29671
# Q6PCB5               0.600685                   3.43104
# P56537               0.290043                  0.329122
#
# [4901 rows x 2 columns]

# %%
df_mj_pvals.plot.scatter('Johnston et al. -log10(p)', 'Mayer et al. -log10(p)')
#plt.savefig('data/mj_all_pvalues.png')
plt.show()

# %%
from scipy import stats
stats.pearsonr(df_mj_pvals['Johnston et al. -log10(p)'], df_mj_pvals['Mayer et al. -log10(p)'])
# Out:
# (0.1210941856588171, 1.7908453923741436e-17)

# %%
sig_both = mj_intersection.intersection(set(m_diff),set(j_diff))

# %%
significant_in_either = mj_intersection.intersection(set(m_diff)).union(
    mj_intersection.intersection(set(j_diff)))

# %%
significant_in_either
# Out:
# {'Q6NVY1',
#  'Q9H8H3',
#  'P42765',
#  'A0MZ66',
#  'Q6PJT7',
#  'O00566',
#  'Q8IZE3',
#  'P00352',
#  'Q8NAV1',
#  'Q14997',
#  'P16455',
#  'P25787',
#  'O95400',
#  'Q9UGU5',
#  'Q9BV57',
#  'Q99714',
#  'Q9H7E9',
#  'Q07065',
#  'Q9UJS0',
#  'Q9NUL3',
#  'Q8TBX8',
#  'Q9BYC5',
#  'Q15014',
#  'Q9UBQ7',
#  'Q13029',
#  'Q15287',
#  'Q86SE9',
#  'O00139',
#  'Q8IYJ3',
#  'Q9UPU5',
#  'Q9BTL3',
#  'P28288',
#  'Q9GZR2',
#  'Q9C005',
#  'Q9Y2H0',
#  'P62253',
#  'Q15428',
#  'Q9UNF0',
#  'Q14624',
#  'Q13188',
#  'O15182',
#  'Q9BY42',
#  'Q7Z3J2',
#  'P17612',
#  'O95819',
#  'Q9NQP4',
#  'Q9NVJ2',
#  'P25205',
#  'Q9HCU8',
#  'P56385',
#  'Q9Y4C1',
#  'P52657',
#  'Q9Y314',
#  'Q96E39',
#  'Q9H7Z6',
#  'P51991',
#  'P62072',
#  'Q7Z7G1',
#  'Q5T0D9',
#  'P46977',
#  'Q9H6A0',
#  'P14550',
#  'P37268',
#  'O60443',
#  'P51608',
#  'Q9NQG5',
#  'Q9H9Q2',
#  'Q9Y3E0',
#  'Q9BQ61',
#  'Q9HCE1',
#  'P27694',
#  'P78406',
#  'Q13263',
#  'Q96DA6',
#  'P54198',
#  'O75223',
#  'P01876',
#  'P17050',
#  'Q9BZ23',
#  'O75064',
#  'Q9ULT0',
#  'O00214',
#  'Q8IX07',
#  'P15924',
#  'O14828',
#  'O94886',
#  'Q9BVP2',
#  'Q8IUE6',
#  'P29122',
#  'O95628',
#  'Q9BYE7',
#  'P01880',
#  'Q5T8P6',
#  'O75475',
#  'P13612',
#  'P48634',
#  'P05556',
#  'P19634',
#  'Q8TBF4',
#  'O75477',
#  'Q8NAP3',
#  'Q9BX67',
#  'O60568',
#  'P17931',
#  'Q8TEH3',
#  'Q99497',
#  'Q8TCT9',
#  'Q8NBM8',
#  'Q6ICG6',
#  'O75146',
#  'Q3V6T2',
#  'Q06187',
#  'O43175',
#  'Q99704',
#  'Q9Y4X4',
#  'Q9UBW7',
#  'Q6UWL2',
#  'Q96EH3',
#  'Q9ULC5',
#  'Q96BZ4',
#  'O75828',
#  'O00410',
#  'O75818',
#  'Q9H019',
#  'Q02535',
#  'P61604',
#  'P14222',
#  'Q9HAS0',
#  'P61978',
#  'Q9BWM7',
#  'Q15084',
#  'P49758',
#  'Q6GPH4',
#  'P52790',
#  'Q9NX58',
#  'Q8TDN6',
#  'Q8TDX7',
#  'Q14894',
#  'P40259',
#  'Q4G176',
#  'Q9Y2L6',
#  'Q9UKV3',
#  'P11234',
#  'Q9H6F5',
#  'Q8WUI4',
#  'Q9UII2',
#  'Q5VWX1',
#  'Q96P70',
#  'Q5T160',
#  'Q6ZMU5',
#  'Q92544',
#  'O00193',
#  'O15127',
#  'P19971',
#  'Q9C035',
#  'P08603',
#  'P08246',
#  'Q06546',
#  'Q71F56',
#  'O60784',
#  'Q9H9B1',
#  'Q96FX7',
#  'P53814',
#  'Q14108',
#  'Q8WVC0',
#  'P67812',
#  'P35659',
#  'Q9UBS4',
#  'Q9NWS8',
#  'P52597',
#  'P17812',
#  'Q14289',
#  'Q8IU81',
#  'Q0VD83',
#  'Q8IYB3',
#  'P27797',
#  'Q9NPJ3',
#  'Q9Y3D3',
#  'Q99952',
#  'O95336',
#  'P13762',
#  'O94903',
#  'P49959',
#  'Q9UBB5',
#  'P56962',
#  'P80723',
#  'Q17R31',
#  'Q9HBI0',
#  'Q92784',
#  'Q8WYH8',
#  'Q14320',
#  'Q9NQS1',
#  'O75391',
#  'Q14667',
#  'Q9NRF8',
#  'Q13325',
#  'P49591',
#  'Q99729',
#  'P62495',
#  'A8MW92',
#  'Q63ZY3',
#  'O94929',
#  'Q9NQ29',
#  'Q13242',
#  'Q9UDR5',
#  'P36776',
#  'Q15118',
#  'Q5T3F8',
#  'P21980',
#  'Q92520',
#  'Q96FV2',
#  'P00387',
#  'Q9Y375',
#  'P23634',
#  'O43290',
#  'Q5SSJ5',
#  'P09471',
#  'Q9UKZ1',
#  'Q9BTT0',
#  'P07311',
#  'P55081',
#  'P30291',
#  'P04003',
#  'Q15771',
#  'Q15172',
#  'P54577',
#  'P51798',
#  'Q14BN4',
#  'Q9Y315',
#  'Q86TM6',
#  'Q15477',
#  'Q8WW59',
#  'Q684P5',
#  'Q9UBU8',
#  'O00442',
#  'P25942',
#  'Q99496',
#  'Q96FI4',
#  'O14602',
#  'O95571',
#  'Q96MU7',
#  'P04114',
#  'O95931',
#  'Q9H4X1',
#  'Q7Z5J4',
#  'Q6NTE8',
#  'P42229',
#  'P51948',
#  'P51148',
#  'O43852',
#  'Q9Y6J0',
#  'Q15652',
#  'Q13459',
#  'Q05D32',
#  'P10619',
#  'Q07666',
#  'P51784',
#  'Q14566',
#  'Q7Z6E9',
#  'Q9UPT8',
#  'P46939',
#  'Q6DN90',
#  'P13765',
#  'Q9NP61',
#  'P49006',
#  'P52565',
#  'Q9BV79',
#  'Q13162',
#  'P24752',
#  'Q9NYV4',
#  'Q8NEY8',
#  'P15336',
#  'Q08257',
#  'Q6K0P9',
#  'P22626',
#  'P53990',
#  'P53992',
#  'Q86YV0',
#  'P23193',
#  'Q8TBP6',
#  'P30086',
#  'O14686',
#  'Q96T58',
#  'O96017',
#  'P55795',
#  'Q96CM8',
#  'Q69YN2',
#  'P17927',
#  'Q9BQG0',
#  'Q8WY91',
#  'P23743',
#  'Q8IU85',
#  'P61626',
#  'Q12797',
#  'Q14008',
#  'P26368',
#  'P07858',
#  'P45983',
#  'P33240',
#  'Q96E29',
#  'O43795',
#  'P61106',
#  'Q8NFW8',
#  'O95394',
#  'Q96HQ2',
#  'Q9BZF9',
#  'Q14318',
#  'P36954',
#  'Q9BUB5',
#  'Q96RG2',
#  'Q92734',
#  'Q8IWA5',
#  'Q9H0G5',
#  'Q15054',
#  'P22694',
#  'Q96KP1',
#  'Q8IUR6',
#  'P52888',
#  'Q15762',
#  'P06734',
#  'Q9UK41',
#  'O75164',
#  'Q7Z3V4',
#  'Q96T66',
#  'P49459',
#  'Q8TEM1',
#  'Q14257',
#  'Q96A57',
#  'Q8IY95',
#  'Q99436',
#  'Q14149',
#  'P07237',
#  'Q9UDT6',
#  'P08571',
#  'Q9NTJ5',
#  'P55008',
#  'Q8TCJ2',
#  'Q9ULZ3',
#  'Q9HCC0',
#  'Q07817',
#  'Q8WXA9',
#  'P11836',
#  'Q9H792',
#  'Q13094',
#  'Q8TAD8',
#  'P62820',
#  'Q5JSH3',
#  'Q15545',
#  'O00559',
#  'Q2PZI1',
#  'P37173',
#  'Q9H3E2',
#  'P01024',
#  'P13489',
#  'P30084',
#  'Q96CX2',
#  'P01591',
#  'Q9BUN8',
#  'P14854',
#  'Q9Y2G3',
#  'Q13123',
#  'O95983',
#  'Q8N2M8',
#  'Q13496',
#  'Q8IY33',
#  'P07332',
#  'Q9H714',
#  'Q9NX20',
#  'Q9UGY1',
#  'Q2KHT3',
#  'Q9ULI0',
#  'P56277',
#  'Q9H6Z4',
#  'P16219',
#  'P12270',
#  'P09917',
#  'Q8TA86',
#  'P26447',
#  'Q13423',
#  'Q86TG7',
#  'Q9Y6A4',
#  'P45985',
#  'Q12905',
#  'O15379',
#  'O00461',
#  'Q86WI1',
#  'Q12765',
#  'Q96FS4',
#  'Q9UH62',
#  'P25325',
#  'Q9UHG3',
#  'P12694',
#  'Q96K49',
#  'Q9Y5Y6',
#  'Q8IXK0',
#  'Q96RQ3',
#  'O75368',
#  'Q9H2F5',
#  'Q9ULV3',
#  'Q9NRP2',
#  'P83436',
#  'P21291',
#  'P51692',
#  'Q9GZY6',
#  'O95644',
#  'Q96FJ0',
#  'Q8N4T8',
#  'Q92576',
#  'Q8NE62',
#  'Q9NWB6',
#  'Q8N0X4',
#  'P82933',
#  'O60667',
#  'Q8N0W3',
#  'Q7Z434',
#  'O60268',
#  'Q9UGM6',
#  'Q01970',
#  'P63279',
#  'Q6NUQ1',
#  'Q8NG11',
#  'Q8TEX9',
#  'Q13573',
#  'Q15628',
#  'Q5JVS0',
#  'Q8N5K1',
#  'P13498',
#  'Q86U44',
#  'P06239',
#  'Q13505',
#  'Q86UT6',
#  'O75817',
#  'Q9BYC9',
#  'Q9NS23',
#  'Q9P260',
#  'Q8WXF1',
#  'Q9NXH8',
#  'Q14202',
#  'Q7L7X3',
#  'O75947',
#  'Q7Z7F0',
#  'O00400',
#  'Q8IY22',
#  'P13667',
#  'Q10472',
#  'P15907',
#  'Q96LA5',
#  'Q52LJ0',
#  'Q9UK45',
#  'Q9NUP1',
#  'Q5T2E6',
#  'Q9Y2W1',
#  'Q658Y4',
#  'Q9H9G7',
#  'P18433',
#  'Q09472',
#  'P37837',
#  'Q9P0W2',
#  'Q8TAQ2',
#  'O60879',
#  'Q09666',
#  'Q6XQN6',
#  'O75962',
#  'O60716',
#  'Q9UHQ4',
#  'Q8WV92',
#  'P63272',
#  'Q96KR1',
#  'Q969T9',
#  'Q15233',
#  'Q969M1',
#  'O43149',
#  'P23368',
#  'Q96FZ2',
#  'P42892',
#  'O95373',
#  'Q4G0F5',
#  'Q9Y487',
#  'P41212',
#  'Q96ES7',
#  'O00479',
#  'P09211',
#  'P43405',
#  'Q8TD55',
#  'P45973',
#  'O00159',
#  'P28907',
#  'Q96BN8',
#  'P49458',
#  'A4D1P6',
#  'Q01973',
#  'A3KN83',
#  'Q8N9U0',
#  'Q9NQY0',
#  'Q14392',
#  'P55345',
#  'Q9BTW9',
#  'Q9BYV8',
#  'P21589',
#  'P42898',
#  'P24158',
#  'Q8NHG7',
#  'P48736',
#  'O95081',
#  'Q96QD9',
#  'Q15036',
#  'Q9NRV9',
#  'Q6PCB8',
#  'Q96AE4',
#  'Q8WUB8',
#  'Q9BRJ7',
#  'Q15067',
#  'Q9UEU0',
#  'Q6NZY4',
#  'Q14C86',
#  'P08133',
#  'Q96T23',
#  'Q5BJF6',
#  'O94766',
#  'Q9UJ70',
#  'Q9HAN9',
#  'P98194',
#  'P07737',
#  'P08397',
#  'O15118',
#  'Q8N4C6',
#  'P23458',
#  'Q9UGI8',
#  'Q9HD45',
#  'O15231',
#  'P23786',
#  'P39019',
#  'Q96BD5',
#  'Q6NWY9',
#  'Q9BR77',
#  'Q6UN15',
#  'O15042',
#  'P20701',
#  'O75439',
#  'Q10570',
#  'Q9UKY7',
#  'Q9NW15',
#  'Q9UDY8',
#  'Q9UHB6',
#  'Q9NTZ6',
#  'Q9ULM3',
#  'Q8IVG5',
#  'O43293',
#  'Q02539',
#  'P34932',
#  'P35637',
#  'P28290',
#  'P29144',
#  'Q92667',
#  'A6NHR9',
#  'Q7L4P6',
#  'P09913',
#  'Q9BTE3',
#  'Q9Y5V0',
#  'O43521',
#  'C9JLW8',
#  'Q8N884',
#  'Q9Y6E2',
#  'P35612',
#  'P13804',
#  'Q02952',
#  'Q6IC98',
#  'P49914',
#  'O14657',
#  'Q7L591',
#  'P23443',
#  'Q16799',
#  'Q9NP72',
#  'P11137',
#  'Q8N1Q1',
#  'O75937',
#  'Q6ZS81',
#  'P11216',
#  'P35221',
#  'Q6UB99',
#  'O43237',
#  'Q14978',
#  'P17480',
#  'Q9HB40',
#  'Q9UBM7',
#  'Q12888',
#  'Q6PJF5',
#  'Q96PK6',
#  'Q8N697',
#  'P11171',
#  'Q1KMD3',
#  'P05165',
#  'P18065',
#  'Q9Y3E1',
#  'Q9H2G2',
#  'P09914',
#  'O14530',
#  'Q9NV88',
#  'Q9H4Z3',
#  'P52272',
#  'O00602',
#  'O00501',
#  'Q96FZ7',
#  'Q96PE3',
#  'P35914',
#  'Q14739',
#  'P09327',
#  'O43390',
#  'Q52LA3',
#  'Q9P2G3',
#  'Q53FA7',
#  'Q2PPJ7',
#  'P11912',
#  'Q6P3W7',
#  'P42126',
#  'P84090',
#  'Q9UKJ3',
#  'Q6IAA8',
#  'Q9Y5S9',
#  'O15014',
#  'Q9Y388',
#  'Q86TU7',
#  'Q5JTZ9',
#  'Q13114',
#  'Q5T013',
#  'Q6UX71',
#  'P55145',
#  'P33993',
#  'Q14643',
#  'Q96P31',
#  'P23246',
#  'Q9H6S3',
#  'P16157',
#  'Q9UBL3',
#  'P52306',
#  'Q9NPJ8',
#  'Q96NB3',
#  'O14949',
#  'P48960',
#  'P04083',
#  'Q6NYC8',
#  'Q96RD9',
#  'Q15424',
#  'Q08170',
#  'Q9C086',
#  'P02794',
#  'Q12778',
#  'Q6WCQ1',
#  'Q15061',
#  'Q9UK61',
#  'Q9UK53',
#  'P30203',
#  'Q9H0C8',
#  'Q9UKI8',
#  'Q9BZQ8',
#  'O43598',
#  'Q5M775',
#  'Q9NYF8',
#  'O43491',
#  'Q8N108',
#  'Q9Y2X7',
#  'Q8N5M1',
#  'Q12768',
#  'B0I1T2',
#  'Q8IWV8',
#  'O15111',
#  'Q8IWZ8',
#  'P62306',
#  'O60292',
#  'P00813',
#  'Q92499',
#  'P35754',
#  'Q8WXF7',
#  'Q8IVT5',
#  'P01042',
#  'Q0JRZ9',
#  'O94768',
#  'Q8IYQ7',
#  'Q6PI98',
#  'Q9Y5W9',
#  'O94888',
#  'O14933',
#  'Q12912',
#  'Q9H8G2',
#  'Q92820',
#  'P02649',
#  'P30047',
#  'P01833',
#  'P17844',
#  'Q6BCY4',
#  'P18085',
#  'Q96RF0',
#  'O60783',
#  'Q2TAY7',
#  'P53004',
#  'Q9P2R3',
#  'P18031',
#  'Q9Y2L9',
#  'Q02750',
#  'Q9UJY5',
#  'Q99943',
#  'Q9Y6D6',
#  'Q02252',
#  'Q96TA1',
#  'O60381',
#  'Q9Y2H2',
#  'Q96RL7',
#  'Q92851',
#  'P09038',
#  'Q9NPJ6',
#  'Q7Z4H7',
#  'Q9Y2Y1',
#  'Q7L4I2',
#  'Q03518',
#  'Q9BPW8',
#  'O14618',
#  'Q9BUQ8',
#  'Q9Y2Q3',
#  'Q5T1M5',
#  'Q32P41',
#  'Q9UKW4',
#  'P32455',
#  'Q92506',
#  'Q15311',
#  'Q9H7B4',
#  'P37198',
#  'Q99549',
#  'Q9BRT2',
#  'P02787',
#  'Q15020',
#  'Q96EL2',
#  'Q8N1B4',
#  'P59768',
#  'Q8TF01',
#  'Q04760',
#  'Q6P3S6',
#  'Q9UN19',
#  'O60547',
#  'P17535',
#  'Q9NQC3',
#  'P32456',
#  'Q96M96',
#  'Q00403',
#  'Q9H4G4',
#  'Q8WUZ0',
#  'Q8NEF9',
#  'Q14683',
#  'P0C7P3',
#  'Q8IXT5',
#  'Q13363',
#  'O43395',
#  'Q9BSD7',
#  'O15504',
#  'O94925',
#  'Q9NQH7',
#  'P04196',
#  'P05114',
#  'P62995',
#  'O14908',
#  'P15104',
#  'Q16658',
#  'Q9NUA8',
#  'Q9H9H4',
#  'Q9Y5L0',
#  'Q92766',
#  'Q9BXP5',
#  'Q15427',
#  'P61201',
#  'Q8N3Z6',
#  'P43243',
#  'P43403',
#  'Q12962',
#  'Q86X95',
#  'Q9NPA8',
#  'P00441',
#  'O75575',
#  'Q06547',
#  'P15311',
#  'Q15389',
#  'Q5VWQ0',
#  'Q96GM5',
#  'O75533',
#  'Q9UHN6',
#  'Q9NR28',
#  'Q6ZS10',
#  'Q15742',
#  'Q9BXY0',
#  'P10301',
#  'Q96HR3',
#  'Q92890',
#  'Q8NBF2',
#  'P05026',
#  'Q15185',
#  'Q9NZL9',
#  'Q15024',
#  'Q15393',
#  'Q4VC05',
#  'Q9C0J8',
#  'Q9UK59',
#  'P55011',
#  'Q5VZE5',
#  'Q8TAV0',
#  'Q96K19',
#  'Q08722',
#  'Q5VT52',
#  'Q99523',
#  'Q9ULS5',
#  'P18084',
#  'Q8WWI5',
#  'P11274',
#  'Q9UII4',
#  'B7ZAP0',
#  'Q969X0',
#  'P23381',
#  'Q9UID3',
#  'Q9H7D0',
#  'Q2M385',
#  'Q7Z4V5',
#  'Q9Y6Q9',
#  'Q7Z6P3',
#  'Q92600',
#  'Q5VZK9',
#  'Q96BZ8',
#  'O00160',
#  'Q05397',
#  'O15211',
#  'O75503',
#  'P55060',
#  'Q6ZNJ1',
#  'Q9Y2Q0',
#  'P20273',
#  'Q9HCM1',
#  'P20810',
#  'Q9BY50',
#  'Q8N103',
#  'Q9BRR8',
#  'Q9HCN8',
#  'O75531',
#  'Q8ND71',
#  'P42166',
#  'Q9UP83',
#  'P41223',
#  'Q9Y4H4',
#  'P27540',
#  'Q9Y618',
#  'Q8WXE9',
#  'Q15047',
#  'O14548',
#  'Q14116',
#  'Q13620',
#  'Q9UPN4',
#  'Q8NDH3',
#  'Q4L180',
#  'Q15126',
#  'Q8WVV9',
#  'O15519',
#  'Q9UQR1',
#  'P01011',
#  'O14733',
#  'O00425',
#  'Q8WU79',
#  'Q86TJ2',
#  'P40818',
#  'Q92608',
#  'Q27J81',
#  'P78417',
#  'Q92673',
#  'Q9P0J7',
#  'Q53TQ3',
#  'P07741',
#  'Q96ND0',
#  'Q9C0C9',
#  'Q05BQ5',
#  'Q9NQW7',
#  'Q96PC3',
#  'P20160',
#  'Q9UIF9',
#  'Q6YHU6',
#  'Q9NVH0',
#  'P51648',
#  'P20023',
#  'P34897',
#  'Q86T03',
#  'Q86V81',
#  'Q9P2A4',
#  'P56377',
#  'P15498',
#  'Q9P0U4',
#  'Q14696',
#  'P61457',
#  'Q8N5A5',
#  'P08311',
#  'Q8N6S5',
#  'O14879',
#  'O75940',
#  'P09601',
#  'Q70Z53',
#  'P14151',
#  'Q9BTT4',
#  'O15229',
#  'Q6XZF7',
#  'Q86YV5',
#  'Q8IX19',
#  'Q05048',
#  'Q9Y3Z3',
#  'P05090',
#  'Q9NRG9',
#  'O75554',
#  'P01859',
#  'P48728',
#  'P42285',
#  'Q92466',
#  'Q13395',
#  'P52701',
#  'P04440',
#  'Q8N0X7',
#  'Q8WXI9',
#  'Q7Z7K6',
#  'O00750',
#  'Q99590',
#  'Q149N8',
#  'Q9HBM6',
#  'P60174',
#  'Q9Y4L1',
#  'P57678',
#  'Q7Z7A4',
#  'Q9H7L9',
#  'Q8NFZ0',
#  'Q8IV08',
#  'Q9GZR7',
#  'Q9Y294',
#  'Q14164',
#  'O15050',
#  'P08240',
#  'P05164',
#  'Q6P3X3',
#  'O15031',
#  'O15327',
#  'P07602',
#  'Q9HB19',
#  'P62312',
#  'P60953',
#  'P16401',
#  'P46926',
#  'Q00978',
#  'Q9BYT8',
#  'Q9NQZ5',
#  'Q96DH6',
#  'Q9UPR0',
#  'Q9UGJ1',
#  'Q9NPI6',
#  'O15020',
#  'Q8NI37',
#  'Q96QC0',
#  'Q7L775',
#  'Q9NVH6',
#  'Q96CN9',
#  'P47755',
#  'P09012',
#  'P49841',
#  'Q9NZR1',
#  'P00403',
#  'Q9BUL5',
#  'P06702',
#  'O43318',
#  'Q9BSV6',
#  'P10412',
#  'P04040',
#  'Q12802',
#  'Q13616',
#  'Q9NUY8',
#  'P60842',
#  'P55212',
#  'P08648',
#  'P08195',
#  'O95544',
#  'Q9HAF1',
#  'Q93073',
#  'Q92614',
#  'Q9H446',
#  'Q99547',
#  'Q99733',
#  'Q13435',
#  'Q8N5W9',
#  'P29372',
#  'Q10469',
#  'Q8WU39',
#  'P46527',
#  'P19174',
#  'Q9BW60',
#  'Q05519',
#  'Q14CX7',
#  'O94915',
#  'Q96SW2',
#  'Q9Y608',
#  'O00170',
#  'Q12906',
#  'Q9HB21',
#  'Q10713',
#  'O43847',
#  ...}

# %%
df_mj_pvals_sig_in_either = pd.DataFrame(index = list(significant_in_either), columns = 
                           ['Mayer et al. -log10(p)', 'Johnston et al. -log10(p)'])

for i in significant_in_either:
    val = float(mayer_p[mayer_p['Protein IDs']==i]["Student's t-test p-value CLL vs  elderly B cells"])
    df_mj_pvals_sig_in_either.loc[i, 'Mayer et al. -log10(p)'] = -log10(val)#since this is p and the other is -log(p)
    
    valj = float(j_p[j_p['Protein group accession']==i]["-Log10(p value)"])
    df_mj_pvals_sig_in_either.loc[i,'Johnston et al. -log10(p)'] = valj

# %%
df_mj_pvals_sig_in_either
# Out:
#        Mayer et al. -log10(p) Johnston et al. -log10(p)
# Q6NVY1               0.713492                   3.39857
# Q9H8H3                2.03951                   1.90002
# P42765                  3.444                   3.17895
# A0MZ66               0.196665                   3.20688
# Q6PJT7               0.444994                   4.55931
# ...                       ...                       ...
# Q01459                2.54819                   1.45813
# Q9NWH9                2.68009                    4.5221
# Q15836               0.223431                   2.66753
# O75695              0.0565243                    4.2936
# Q9Y5X1                3.56097                   2.76354
#
# [1239 rows x 2 columns]

# %%
df_mj_pvals_sig_in_either.plot.scatter('Johnston et al. -log10(p)', 'Mayer et al. -log10(p)')
plt.axhline(-log10(.05), color ='orange')
plt.axvline(-log10(.05), color ='orange')
#plt.savefig('data/mj_sig-in-both_pvalues.png')

# %%
stats.pearsonr(df_mj_pvals_sig_in_either['Johnston et al. -log10(p)'], df_mj_pvals_sig_in_either['Mayer et al. -log10(p)'])
# Out:
# (-0.20182919582138803, 7.443974290859802e-13)
