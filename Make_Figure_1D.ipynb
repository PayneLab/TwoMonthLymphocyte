# %% [markdown]
# ## B cells versus T cells
# The data used in this notebook is lymphocyte data for subject 1's B cells and T cells. We use this data to show the proteome variation between the cell types. Here, we note presence/absense changes and quantify fold changes using a T test.

# %%
import longitudinalCLL
import matplotlib.pyplot as plt
import seaborn as sns
from numpy import log10
import numpy as np
import pandas as pd
from gprofiler import GProfiler
import numpy as np
from statistics import mean

# %% [markdown]
# ### Access data
# First, we import our data package. This brings the functions defined there into scope so we can use them in this script. Then we can create a proteomic dataset object and store it as <code>prot</code>. You can select versions and subjects with <code>load_dataset</code>.
#
# Calling <code>head</code> shows the first several lines of the dataframe, which provides an idea of the type of data present and the structure of the dataframe.

# %%
prot = longitudinalCLL.get_proteomic()
prot.load_dataset(version='July_noMBR_FP', subjects = [1])
prot.data_raw.head()
# Out:
#             Subject1_B_cells_062920_C_10  Subject1_B_cells_062920_C_11  \
# Protein ID
# A0A0B4J2D5                     3203277.5                     4697996.0
# A0AVT1                         1917388.2                     3033529.2
# A0FGR8                               0.0                           0.0
# A6NHR9                         2650513.5                           0.0
# A8K2U0                               0.0                           0.0
#
#             Subject1_B_cells_062920_C_12  Subject1_B_cells_062920_C_13  \
# Protein ID
# A0A0B4J2D5                     7346776.5                     8472867.0
# A0AVT1                         3773018.8                     1865758.6
# A0FGR8                               0.0                           0.0
# A6NHR9                         3788095.8                           0.0
# A8K2U0                               0.0                     1149867.8
#
#             Subject1_B_cells_062920_C_9  Subject1_B_cells_072920_C_4  \
# Protein ID
# A0A0B4J2D5                    4280919.5                          0.0
# A0AVT1                        5191332.5                    3332031.5
# A0FGR8                              0.0                          0.0
# A6NHR9                              0.0                    1845555.5
# A8K2U0                              0.0                          0.0
#
#             Subject1_B_cells_072920_C_5  Subject1_B_cells_072920_C_6  \
# Protein ID
# A0A0B4J2D5                   4787781.50                    2153860.2
# A0AVT1                       2464089.00                    2290868.2
# A0FGR8                             0.00                          0.0
# A6NHR9                        933499.44                    1958162.5
# A8K2U0                             0.00                          0.0
#
#             Subject1_B_cells_072920_C_8  Subject1_B_cells_072920_C_9  \
# Protein ID
# A0A0B4J2D5                    5444238.5                   5514300.50
# A0AVT1                        2486001.2                   2596365.20
# A0FGR8                              0.0                         0.00
# A6NHR9                        1604476.4                    418360.38
# A8K2U0                        2272656.2                         0.00
#
#             Subject1_T_cells_062920_D_10  Subject1_T_cells_062920_D_11  \
# Protein ID
# A0A0B4J2D5                     1452451.2                           0.0
# A0AVT1                               0.0                     2869977.5
# A0FGR8                               0.0                           0.0
# A6NHR9                          907359.0                           0.0
# A8K2U0                               0.0                           0.0
#
#             Subject1_T_cells_062920_D_12  Subject1_T_cells_062920_D_13  \
# Protein ID
# A0A0B4J2D5                     219754.92                          0.00
# A0AVT1                              0.00                          0.00
# A0FGR8                              0.00                          0.00
# A6NHR9                              0.00                     159779.72
# A8K2U0                              0.00                          0.00
#
#             Subject1_T_cells_062920_D_9  Subject1_T_cells_072920_D_2  \
# Protein ID
# A0A0B4J2D5                     679607.9                   2275364.50
# A0AVT1                        1394525.6                   2804357.20
# A0FGR8                              0.0                    756851.44
# A6NHR9                              0.0                         0.00
# A8K2U0                              0.0                         0.00
#
#             Subject1_T_cells_072920_D_4  Subject1_T_cells_072920_D_5  \
# Protein ID
# A0A0B4J2D5                    3411472.8                          0.0
# A0AVT1                        1830829.1                    1185091.1
# A0FGR8                              0.0                          0.0
# A6NHR9                              0.0                          0.0
# A8K2U0                              0.0                          0.0
#
#             Subject1_T_cells_072920_D_6  Subject1_T_cells_072920_D_7
# Protein ID
# A0A0B4J2D5                    1205392.9                    1030751.8
# A0AVT1                        1250515.2                    1041313.3
# A0FGR8                              0.0                    1197022.1
# A6NHR9                        1074709.6                          0.0
# A8K2U0                              0.0                          0.0

# %% [markdown]
# Our next steps will require separating the runs by cell type, to compare B cells to T cells. As you see above, the pattern for naming the columns is "Intensity ", B or T indicating cell type, and the replicate number. Here we define the list of cell types that the functions should look for based on the naming pattern.

# %%
cell_types=['Subject1_B_cells_062920', 'Subject1_T_cells_062920']

# %% [markdown]
# Here we record which proteins are only identified in one cell type. We'll set these aside for now, in the <code>data_in_one_type</code> dataframe.
#
# For our analysis, present in more than half, or at least 3 out of 5 replicates, is considered clear although it is interesting to note those proteins identified in all replicates of one type.

# %%
present_only_in = prot.check_presence_absence(min_reps=3, cell_types=cell_types, null_value=0).dropna()

print("Proteins identified only in:")
print(present_only_in.value_counts())
data_in_one_type =prot.data_frame.loc[present_only_in.index]
data_in_one_type['Type'] = present_only_in
# Out:
# Proteins identified only in:
# Subject1_B_cells_062920    77
# Subject1_T_cells_062920    59
# dtype: int64

# %% [markdown]
# The <code>min_reps</code> is the minimum number of replicates required to list a protein as present in one type. This can be changed, i.e., <code>min_reps=5</code> to determine the proteins identified in all 5 replicates of a single type; do not set it to a number greater than the replicates run or no proteins will be returned.

# %%
present_5of5_only_in = prot.check_presence_absence(min_reps=5, cell_types=cell_types, null_value=0).dropna()

# %%
print("Proteins identified in 5/5 replicates only in:")
print(present_5of5_only_in.value_counts())
data_in_5of5_one_type =prot.data_frame.loc[present_5of5_only_in.index]
data_in_5of5_one_type['Type'] = present_5of5_only_in
# Out:
# Proteins identified in 5/5 replicates only in:
# Subject1_B_cells_062920    30
# Subject1_T_cells_062920    21
# dtype: int64

# %% [markdown]
# Next, we select the proteins that are measured in at least three samples from each group, allowing the calculations to proceed without imputed zero-handling.

# %%
indecies = prot.check_n_of_each_type(cell_types=cell_types, null_value=0)
prot.data_frame = prot.data_frame[indecies]

# %%
print ("Total groups identified:")
print(prot.data_raw.shape[0])

print ("\nTotal groups identified and present at least once:")
print (prot.data_frame.dropna(axis=0, how='all').shape[0])

print ("\nProteins identified in at least 3 of each cell type:\t")
print (prot.data_frame.shape[0])
# Out:
# Total groups identified:
# 2426
#
# Total groups identified and present at least once:
# 1002
#
# Proteins identified in at least 3 of each cell type:
# 1002

# %% [markdown]
# Before any analysis, we log normalize and median normalize across runs. We need to do this after filtering for consistently expressed proteins so those only identified in some rows do not throw off the normalization.

# %%
prot.normalize()
# Out:
#             Subject1_B_cells_062920_C_10  Subject1_B_cells_062920_C_11  \
# Protein ID
# A0A0B4J2D5                     -1.028363                     -0.765797
# O00148                          1.635450                      1.511831
# O00151                          0.242795                      0.207199
# O00170                         -1.535086                     -2.231119
# O00193                               NaN                     -1.703481
# ...                                  ...                           ...
# P0C7X5                          0.050055                     -0.012256
# P62891                         -1.613277                     -1.557996
# Q6BDS2                          4.496551                      2.609288
# Q8NDC0                         -1.675506                     -2.498488
# Q9Y237                         -1.674683                           NaN
#
#             Subject1_B_cells_062920_C_12  Subject1_B_cells_062920_C_13  \
# Protein ID
# A0A0B4J2D5                      0.080103                      0.017329
# O00148                          1.483985                      1.229932
# O00151                          0.094864                      0.086183
# O00170                         -1.601094                           NaN
# O00193                         -2.307610                     -2.149489
# ...                                  ...                           ...
# P0C7X5                               NaN                     -0.410224
# P62891                         -1.620401                     -1.168133
# Q6BDS2                               NaN                           NaN
# Q8NDC0                         -0.795254                     -7.677445
# Q9Y237                               NaN                     -2.150869
#
#             Subject1_B_cells_062920_C_9  Subject1_B_cells_072920_C_4  \
# Protein ID
# A0A0B4J2D5                    -0.808269                          NaN
# O00148                         0.965951                     1.559865
# O00151                         0.016137                     0.814644
# O00170                              NaN                    -1.524664
# O00193                              NaN                          NaN
# ...                                 ...                          ...
# P0C7X5                        -1.017601                          NaN
# P62891                        -1.415135                          NaN
# Q6BDS2                         2.672428                     2.397055
# Q8NDC0                              NaN                    -0.998901
# Q9Y237                        -2.719865                    -2.801068
#
#             Subject1_B_cells_072920_C_5  Subject1_B_cells_072920_C_6  \
# Protein ID
# A0A0B4J2D5                    -0.536486                    -1.668948
# O00148                         1.304222                     1.383576
# O00151                         0.869635                     0.749862
# O00170                        -1.530991                    -1.831965
# O00193                              NaN                    -1.911568
# ...                                 ...                          ...
# P0C7X5                        -1.533485                    -1.242016
# P62891                        -0.681628                    -0.468650
# Q6BDS2                         3.682528                     2.799002
# Q8NDC0                        -1.388340                    -1.155773
# Q9Y237                              NaN                          NaN
#
#             Subject1_B_cells_072920_C_8  Subject1_B_cells_072920_C_9  \
# Protein ID
# A0A0B4J2D5                    -0.453732                    -0.389174
# O00148                         1.100382                     1.135702
# O00151                         0.363598                     0.583909
# O00170                        -1.693674                    -1.121364
# O00193                        -1.310490                          NaN
# ...                                 ...                          ...
# P0C7X5                        -0.897484                    -1.432334
# P62891                        -0.812113                    -0.692241
# Q6BDS2                         1.343294                     3.459470
# Q8NDC0                              NaN                    -1.319587
# Q9Y237                        -2.517838                    -2.526480
#
#             Subject1_T_cells_062920_D_10  Subject1_T_cells_062920_D_11  \
# Protein ID
# A0A0B4J2D5                     -2.270020                           NaN
# O00148                          1.286035                      1.121530
# O00151                               NaN                           NaN
# O00170                         -1.715148                     -1.902660
# O00193                               NaN                     -2.177405
# ...                                  ...                           ...
# P0C7X5                               NaN                      0.200531
# P62891                         -0.810456                     -1.048246
# Q6BDS2                          4.719716                           NaN
# Q8NDC0                         -2.185671                     -2.820653
# Q9Y237                               NaN                     -3.355792
#
#             Subject1_T_cells_062920_D_12  Subject1_T_cells_062920_D_13  \
# Protein ID
# A0A0B4J2D5                     -4.935049                           NaN
# O00148                          1.404171                      1.280990
# O00151                         -3.450727                     -2.344984
# O00170                         -1.201828                     -2.291448
# O00193                               NaN                     -1.028479
# ...                                  ...                           ...
# P0C7X5                         -0.002767                           NaN
# P62891                         -0.175470                     -0.570267
# Q6BDS2                          4.610313                      4.014142
# Q8NDC0                        -11.166108                     -1.838183
# Q9Y237                               NaN                     -2.018399
#
#             Subject1_T_cells_062920_D_9  Subject1_T_cells_072920_D_2  \
# Protein ID
# A0A0B4J2D5                    -3.346052                    -1.563623
# O00148                         1.232748                     1.136505
# O00151                        -2.227299                    -0.692738
# O00170                        -1.961046                    -1.345287
# O00193                        -2.039934                    -4.185355
# ...                                 ...                          ...
# P0C7X5                        -0.014376                    -0.272932
# P62891                        -0.737200                          NaN
# Q6BDS2                         1.425064                     4.400381
# Q8NDC0                              NaN                    -1.369223
# Q9Y237                        -2.597406                          NaN
#
#             Subject1_T_cells_072920_D_4  Subject1_T_cells_072920_D_5  \
# Protein ID
# A0A0B4J2D5                    -0.976691                          NaN
# O00148                         1.073015                     1.085518
# O00151                        -1.374347                    -0.978211
# O00170                        -1.520683                    -1.162608
# O00193                              NaN                    -1.995656
# ...                                 ...                          ...
# P0C7X5                              NaN                          NaN
# P62891                        -0.317462                    -0.281645
# Q6BDS2                         3.787509                     1.001744
# Q8NDC0                        -2.438982                    -1.914657
# Q9Y237                              NaN                          NaN
#
#             Subject1_T_cells_072920_D_6  Subject1_T_cells_072920_D_7
# Protein ID
# A0A0B4J2D5                    -2.496751                    -2.784598
# O00148                         1.291161                     1.210166
# O00151                        -0.986632                    -0.668748
# O00170                        -1.279202                    -1.028724
# O00193                              NaN                    -2.076236
# ...                                 ...                          ...
# P0C7X5                        -0.808574                    -2.935807
# P62891                        -0.213728                    -0.797942
# Q6BDS2                         3.238314                     1.238510
# Q8NDC0                        -2.019755                    -1.722336
# Q9Y237                        -2.973261                          NaN
#
# [1002 rows x 20 columns]

# %% [markdown]
# ### Analysis
#
# Now we calulate p values using a ttest.

# %%
#Call ttest function
tstats = prot.ttest_wrapper(cell_types=cell_types)

# %% [markdown]
# Here we calculate fold change.

# %%
comparison_key = 'log2(B)-log2(T)'

tstats[comparison_key] = prot.get_fold_changes(cell_types=cell_types)

# %% [markdown]
# Fold change and p values allow us to create a volcano plot.

# %%
#graph volcano
tstats['-log p'] = -log10(tstats['pvalue'])

figure = sns.scatterplot(x=comparison_key,y='-log p',data=tstats)

figure.set_title("B cells vs T cells")
#plt.axvline(1, color ='orange')
#plt.axvline(-1, color ='orange')
plt.axhline(-log10(.05), color ='orange')
#plt.savefig('testing/data/B_v_T.png')
plt.show()

# %% [markdown]
# Next we will identify the altered proteins.

# %%
altered = prot.is_altered(tstats, pvalue=.05,
                          change_factor=False,
                          change_col=comparison_key, 
                          cell_types=cell_types)

# %% [markdown]
# These are significantly altered (p<0.05) without restricting by the magnitude of change:

# %%
altered.value_counts()
# Out:
# Subject1_T_cells_062920    123
# Subject1_B_cells_062920     54
# dtype: int64

# %%
print("Here are counts for other p and change cutoffs:")
print("P<0.05, >150% of the other type")
print(prot.is_altered(tstats, pvalue=.05,change_factor=1.5).value_counts()) #50% increase from either
print("\nP<0.05, >200% of the other type")
print(prot.is_altered(tstats, pvalue=.05,change_factor=2).value_counts()) #Double
print("\nP<0.05, >500% of the other type")
print(prot.is_altered(tstats, pvalue=.05,change_factor=5).value_counts()) #5 times larger

print("\nP<0.01, >150% of the other type")
print(prot.is_altered(tstats, pvalue=.01,change_factor=1.5).value_counts()) #50% increase from either
print("\nP<0.01, >200% of the other type")
print(prot.is_altered(tstats, pvalue=.01,change_factor=2).value_counts()) #Double
print("\nP<0.01, >500% of the other type")
print(prot.is_altered(tstats, pvalue=.01,change_factor=5).value_counts()) #5 times larger
# Out:
# Here are counts for other p and change cutoffs:
# P<0.05, >150% of the other type
# T cells    54
# B cells    34
# dtype: int64
#
# P<0.05, >200% of the other type
# T cells    23
# B cells    17
# dtype: int64
#
# P<0.05, >500% of the other type
# T cells    3
# B cells    1
# dtype: int64
#
# P<0.01, >150% of the other type
# T cells    40
# B cells    24
# dtype: int64
#
# P<0.01, >200% of the other type
# T cells    19
# B cells    11
# dtype: int64
#
# P<0.01, >500% of the other type
# T cells    2
# dtype: int64

# %% [markdown]
# ### Differentially expressed proteins

# %%
figure = sns.scatterplot(x=comparison_key,y='-log p',data=tstats)
figure2 = sns.scatterplot(x=comparison_key,y='-log p',
                          data=tstats.loc[altered.index])

y = np.random.randint(low=0, high=11, size=100)
plt.yticks(np.arange(0, max(y), 1))

plt.rc('axes',labelsize=20)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.title("B cells vs T cells Subject 1", fontsize=20)


#plt.savefig('testing/data/B_v_T_1.png', bbox_inches='tight', dpi=300)
# Out:
# Text(0.5, 1.0, 'B cells vs T cells Subject 1')

# %% [markdown]
# This shows the differentially expressed proteins. Recall that this dataset is restricted to those expressed in at least three of each cell type.
#
# The next step is to identify those proteins by name. Here we get the protein names from the fasta file, which remain the same regardless of which software the data was quantified using.

# %% [markdown]
# *Note that this function doesn't really have a place in the new set up yet.*

# %%
def load_fasta(file="longitudinalCLL/data/uniprot-filtered-proteome_3AUP000005640_reviewed_human.fasta"):
    
    #file is formated:
    #>sp|Q96IY4|CBPB2_HUMAN Carboxypeptidase B2 OS=Homo sapiens OX=9606 GN=CPB2 PE=1 SV=2
    #MKLCS...
    headings = {}
    with open(file) as f:
        for line in f:
            if line.startswith('>'):#header line
                ID = line.split('|')[1]
                name=line.split('|')[2].split('=')[0].strip('OS')
                headings[ID]=name
    headings = pd.Series(list(headings.values()), index=headings.keys())
    
    return headings

# %%
protein_names = load_fasta()

# %%
protein_names_by_group={}
for ID in prot.data_raw.index:
    if ';' in ID:
        ids = ID.split(';')
        names=''
        for i in ids:
            if i in protein_names.index:
                names=names + protein_names[i] + ';'
        names = names[:-1]
        protein_names_by_group[ID] = names
    else:
        if ID in protein_names.index:
            protein_names_by_group[ID]=protein_names[ID]
protein_names_by_group = pd.Series(list(protein_names_by_group.values()), index=protein_names_by_group.keys())

# %% [markdown]
# Here we add the names to the <code>tstats</code> dataframe, which contains the fold changes for each protein. Then we can list the proteins that are altered. Optionally, use <code> head()</code> to display the first few or <code>to_csv</code> to write out to a file. We now split up the proteins heightened in B cells from those heightened in T cells.

# %%
tstats['Name']=protein_names_by_group
tstats['GeneID'] = tstats.Name.apply(lambda n: str(n).split('_HUMAN')[0])

altered_proteins = tstats.loc[altered.index].sort_values('log2(B)-log2(T)',
                        ascending=False)[['Name','GeneID','log2(B)-log2(T)','pvalue']]
higher_in_B_cells = altered_proteins.loc[altered_proteins['log2(B)-log2(T)'] >0]
higher_in_T_cells = altered_proteins.loc[altered_proteins['log2(B)-log2(T)'] <0]

#To write out to a file, use:
#altered_proteins.to_csv('data/filename.tsv', sep='\t')

# %% [markdown]
# Next we do the same for those only identified in one cell type.

# %%
data_in_one_type['Name'] = protein_names_by_group
data_in_one_type['GeneID']=data_in_one_type.Name.apply(lambda n: str(n).split('_HUMAN')[0])

B_cell_only_geneset = data_in_one_type[(data_in_one_type.Type==cell_types[0])]
T_cell_only_geneset= data_in_one_type[(data_in_one_type.Type==cell_types[1])]

# %% [markdown]
# ### Proteins Higher in B Cells:

# %%
higher_in_B_cells
# Out:
#                                                          Name GeneID  \
# Protein ID
# Q86Y46          K2C73_HUMAN Keratin, type II cytoskeletal 73   K2C73
# P01834              IGKC_HUMAN Immunoglobulin kappa constant    IGKC
# P09960                 LKHA4_HUMAN Leukotriene A-4 hydrolase   LKHA4
# P10599                                THIO_HUMAN Thioredoxin    THIO
# P09525                                ANXA4_HUMAN Annexin A4   ANXA4
# P18085                  ARF4_HUMAN ADP-ribosylation factor 4    ARF4
# P30040      ERP29_HUMAN Endoplasmic reticulum resident pro...  ERP29
# P29350      PTN6_HUMAN Tyrosine-protein phosphatase non-re...   PTN6
# P0DOY2          IGLC2_HUMAN Immunoglobulin lambda constant 2   IGLC2
# Q96KP4        CNDP2_HUMAN Cytosolic non-specific dipeptidase   CNDP2
# P07203                   GPX1_HUMAN Glutathione peroxidase 1    GPX1
# P09874            PARP1_HUMAN Poly [ADP-ribose] polymerase 1   PARP1
# P27707                        DCK_HUMAN Deoxycytidine kinase     DCK
# P14550      AK1A1_HUMAN Aldo-keto reductase family 1 membe...  AK1A1
# Q9P258                               RCC2_HUMAN Protein RCC2    RCC2
# P58546                                 MTPN_HUMAN Myotrophin    MTPN
# P62993      GRB2_HUMAN Growth factor receptor-bound protei...   GRB2
# P59666                      DEF3_HUMAN Neutrophil defensin 3    DEF3
# P15531            NDKA_HUMAN Nucleoside diphosphate kinase A    NDKA
# P22392            NDKB_HUMAN Nucleoside diphosphate kinase B    NDKB
# P02814      MR3B_HUMAN Submaxillary gland androgen-regulat...   MR3B
# Q16666      IF16_HUMAN Gamma-interferon-inducible protein 16    IF16
# P00491            PNPH_HUMAN Purine nucleoside phosphorylase    PNPH
# Q01105                                  ET_HUMAN Protein SET      ET
# P05387            RLA2_HUMAN 60S acidic ribosomal protein P2    RLA2
# P50395        GDIB_HUMAN Rab GDP dissociation inhibitor beta    GDIB
# Q15084            PDIA6_HUMAN Protein disulfide-isomerase A6   PDIA6
# P09211               GSTP1_HUMAN Glutathione S-transferase P   GSTP1
# Q9BVC6                 TM109_HUMAN Transmembrane protein 109   TM109
# Q04760                   LGUL_HUMAN Lactoylglutathione lyase    LGUL
# P41240                 CSK_HUMAN Tyrosine-protein kinase CSK     CSK
# P27695      APEX1_HUMAN DNA-(apurinic or apyrimidinic site...  APEX1
# P53396                       ACLY_HUMAN ATP-citrate synthase    ACLY
# Q9BTT0      AN32E_HUMAN Acidic leucine-rich nuclear phosph...  AN32E
# Q9UJU6                       DBNL_HUMAN Drebrin-like protein    DBNL
# Q06830                           PRDX1_HUMAN Peroxiredoxin-1   PRDX1
# O14979      HNRDL_HUMAN Heterogeneous nuclear ribonucleopr...  HNRDL
# P31150       GDIA_HUMAN Rab GDP dissociation inhibitor alpha    GDIA
# P51149                RAB7A_HUMAN Ras-related protein Rab-7a   RAB7A
# Q14103      HNRPD_HUMAN Heterogeneous nuclear ribonucleopr...  HNRPD
# P62937      PPIA_HUMAN Peptidyl-prolyl cis-trans isomerase A    PPIA
# P16401                                H15_HUMAN Histone H1.5     H15
# P05141                      ADT2_HUMAN ADP/ATP translocase 2    ADT2
# P15311                                      EZRI_HUMAN Ezrin    EZRI
# P17858      PFKAL_HUMAN ATP-dependent 6-phosphofructokinas...  PFKAL
# P40925          MDHC_HUMAN Malate dehydrogenase, cytoplasmic    MDHC
# P12236                      ADT3_HUMAN ADP/ATP translocase 3    ADT3
# P20340                RAB6A_HUMAN Ras-related protein Rab-6A   RAB6A
# P31939      PUR9_HUMAN Bifunctional purine biosynthesis pr...   PUR9
# Q99623                               PHB2_HUMAN Prohibitin-2    PHB2
# P55072      TERA_HUMAN Transitional endoplasmic reticulum ...   TERA
# Q14697              GANAB_HUMAN Neutral alpha-glucosidase AB   GANAB
# Q00610                     CLH1_HUMAN Clathrin heavy chain 1    CLH1
# P20700                                  LMNB1_HUMAN Lamin-B1   LMNB1
#
#             log2(B)-log2(T)        pvalue
# Protein ID
# Q86Y46             2.824465  2.870075e-02
# P01834             2.037728  7.591636e-03
# P09960             1.882577  2.879600e-07
# P10599             1.699129  2.781215e-02
# P09525             1.684082  3.593305e-05
# P18085             1.668645  4.983910e-02
# P30040             1.567264  5.924181e-04
# P29350             1.533667  8.575830e-09
# P0DOY2             1.518162  2.321131e-04
# Q96KP4             1.385855  2.804861e-06
# P07203             1.283684  2.710665e-02
# P09874             1.237545  6.450261e-07
# P27707             1.214726  5.828770e-04
# P14550             1.093682  2.467343e-02
# Q9P258             1.031687  8.415768e-03
# P58546             1.013637  5.935683e-03
# P62993             1.004371  2.073324e-02
# P59666             0.935758  5.250980e-05
# P15531             0.926414  4.064088e-03
# P22392             0.913879  4.518743e-03
# P02814             0.891725  3.206501e-02
# Q16666             0.876221  5.242861e-03
# P00491             0.869822  1.945220e-02
# Q01105             0.820460  6.726300e-04
# P05387             0.817468  3.849556e-02
# P50395             0.803460  3.403279e-04
# Q15084             0.795450  4.751221e-03
# P09211             0.770165  8.535731e-03
# Q9BVC6             0.736058  2.472595e-02
# Q04760             0.725802  1.551732e-03
# P41240             0.700792  1.283305e-03
# P27695             0.682219  7.987904e-04
# P53396             0.636711  3.362100e-04
# Q9BTT0             0.614641  7.407104e-03
# Q9UJU6             0.577371  7.961814e-04
# Q06830             0.570775  2.576009e-03
# O14979             0.524099  1.946796e-02
# P31150             0.519878  3.028830e-02
# P51149             0.445407  2.241778e-03
# Q14103             0.437007  1.070645e-02
# P62937             0.403781  6.996994e-03
# P16401             0.402561  4.089186e-02
# P05141             0.394436  2.226339e-02
# P15311             0.368974  1.056673e-02
# P17858             0.366647  2.635926e-02
# P40925             0.338586  5.340233e-04
# P12236             0.333605  2.141576e-02
# P20340             0.332856  3.283844e-02
# P31939             0.303303  3.288619e-02
# Q99623             0.272870  3.288040e-02
# P55072             0.262935  3.308283e-02
# Q14697             0.252365  9.225365e-03
# Q00610             0.219474  3.151974e-02
# P20700             0.194511  4.518316e-02

# %% [markdown]
# ### Proteins Only in B Cells:

# %%
B_cell_only_geneset[['Name', 'GeneID']]
# Out:
#                                                          Name GeneID
# Protein ID
# O60262      GBG7_HUMAN Guanine nucleotide-binding protein ...   GBG7
# O60832      DKC1_HUMAN H/ACA ribonucleoprotein complex sub...   DKC1
# O75223             GGCT_HUMAN Gamma-glutamylcyclotransferase    GGCT
# O75608               LYPA1_HUMAN Acyl-protein thioesterase 1   LYPA1
# O75874      IDHC_HUMAN Isocitrate dehydrogenase [NADP] cyt...   IDHC
# ...                                                       ...    ...
# P01877      IGHA2_HUMAN Immunoglobulin heavy constant alph...  IGHA2
# P13498              CY24A_HUMAN Cytochrome b-245 light chain   CY24A
# P60033                               CD81_HUMAN CD81 antigen    CD81
# Q16563               YPL1_HUMAN Synaptophysin-like protein 1    YPL1
# Q8WUW1                             BRK1_HUMAN Protein BRICK1    BRK1
#
# [77 rows x 2 columns]

# %% [markdown]
# ### Proteins higher or only in B cells by GeneID
# <code>B_cell_set</code> is defined here as both the above lists of names, those higher or only in B cells.

# %%
B_cell_set = list(higher_in_B_cells.GeneID)+list(B_cell_only_geneset.GeneID)

# %%
len(B_cell_set)
# Out:
# 131

# %% [markdown]
# ### Proteins Higher in T Cells:

# %%
higher_in_T_cells.sort_values('log2(B)-log2(T)',ascending=True)
# Out:
#                                                          Name GeneID  \
# Protein ID
# O14745      NHRF1_HUMAN Na(+)/H(+) exchange regulatory cof...  NHRF1
# P26447                            10A4_HUMAN Protein S100-A4    10A4
# Q96C19      EFHD2_HUMAN EF-hand domain-containing protein D2   EFHD2
# Q15149                                    PLEC_HUMAN Plectin    PLEC
# Q9Y2Q3         GSTK1_HUMAN Glutathione S-transferase kappa 1   GSTK1
# ...                                                       ...    ...
# P49368          TCPG_HUMAN T-complex protein 1 subunit gamma    TCPG
# P07900           HS90A_HUMAN Heat shock protein HSP 90-alpha   HS90A
# P14618                        KPYM_HUMAN Pyruvate kinase PKM    KPYM
# P31946                 1433B_HUMAN 14-3-3 protein beta/alpha   1433B
# P13639                         EF2_HUMAN Elongation factor 2     EF2
#
#             log2(B)-log2(T)    pvalue
# Protein ID
# O14745            -4.274482  0.000247
# P26447            -3.003878  0.000007
# Q96C19            -2.913300  0.016347
# Q15149            -1.599367  0.000478
# Q9Y2Q3            -1.583877  0.001036
# ...                     ...       ...
# P49368            -0.247307  0.011586
# P07900            -0.246409  0.025096
# P14618            -0.244552  0.028731
# P31946            -0.240875  0.001925
# P13639            -0.203213  0.018418
#
# [123 rows x 4 columns]

# %% [markdown]
# ### Proteins Only in T Cells:

# %%
T_cell_only_geneset[['Name', 'GeneID']]
# Out:
#                                                          Name GeneID
# Protein ID
# O00584                            RNT2_HUMAN Ribonuclease T2    RNT2
# O15117                      FYB1_HUMAN FYN-binding protein 1    FYB1
# O43665       RGS10_HUMAN Regulator of G-protein signaling 10   RGS10
# O60496                          DOK2_HUMAN Docking protein 2    DOK2
# O60610              DIAP1_HUMAN Protein diaphanous homolog 1   DIAP1
# O60880           H21A_HUMAN SH2 domain-containing protein 1A    H21A
# O95571      ETHE1_HUMAN Persulfide dioxygenase ETHE1, mito...  ETHE1
# O95831      AIFM1_HUMAN Apoptosis-inducing factor 1, mitoc...  AIFM1
# O95834      EMAL2_HUMAN Echinoderm microtubule-associated ...  EMAL2
# O95881      TXD12_HUMAN Thioredoxin domain-containing prot...  TXD12
# P01732      CD8A_HUMAN T-cell surface glycoprotein CD8 alp...   CD8A
# P06127             CD5_HUMAN T-cell surface glycoprotein CD5     CD5
# P06729                  CD2_HUMAN T-cell surface antigen CD2     CD2
# P07305                                H10_HUMAN Histone H1.0     H10
# P07766      CD3E_HUMAN T-cell surface glycoprotein CD3 eps...   CD3E
# P12544                                 GRAA_HUMAN Granzyme A    GRAA
# P13164      IFM1_HUMAN Interferon-induced transmembrane pr...   IFM1
# P16150                                LEUK_HUMAN Leukosialin    LEUK
# P30203          CD6_HUMAN T-cell differentiation antigen CD6     CD6
# P42785            PCP_HUMAN Lysosomal Pro-X carboxypeptidase     PCP
# P46976                               GLYG_HUMAN Glycogenin-1    GLYG
# P49863                                 GRAK_HUMAN Granzyme K    GRAK
# P53634                     CATC_HUMAN Dipeptidyl peptidase 1    CATC
# P54577          YYC_HUMAN Tyrosine--tRNA ligase, cytoplasmic     YYC
# Q13094             LCP2_HUMAN Lymphocyte cytosolic protein 2    LCP2
# Q8IV04                                   TB10C_HUMAN Carabin   TB10C
# Q8NHV1               GIMA7_HUMAN GTPase IMAP family member 7   GIMA7
# Q8WWP7               GIMA1_HUMAN GTPase IMAP family member 1   GIMA1
# Q969E4      TCAL3_HUMAN Transcription elongation factor A ...  TCAL3
# Q96B97      H3K1_HUMAN SH3 domain-containing kinase-bindin...   H3K1
# Q96C23                         GALM_HUMAN Aldose 1-epimerase    GALM
# Q9BU61      NDUF3_HUMAN NADH dehydrogenase [ubiquinone] 1 ...  NDUF3
# Q9BUH6                               PAXX_HUMAN Protein PAXX    PAXX
# Q9H9B4                             FXN1_HUMAN Sideroflexin-1    FXN1
# Q9NZ08      ERAP1_HUMAN Endoplasmic reticulum aminopeptida...  ERAP1
# Q9UHL4                     DPP2_HUMAN Dipeptidyl peptidase 2    DPP2
# Q9Y3Z3      AMH1_HUMAN Deoxynucleoside triphosphate tripho...   AMH1
# O94804         TK10_HUMAN Serine/threonine-protein kinase 10    TK10
# P02795                           MT2_HUMAN Metallothionein-2     MT2
# P05023      AT1A1_HUMAN Sodium/potassium-transporting ATPa...  AT1A1
# P23743                DGKA_HUMAN Diacylglycerol kinase alpha    DGKA
# P32455                GBP1_HUMAN Guanylate-binding protein 1    GBP1
# Q16539        MK14_HUMAN Mitogen-activated protein kinase 14    MK14
# P41236            IPP2_HUMAN Protein phosphatase inhibitor 2    IPP2
# Q03519              TAP2_HUMAN Antigen peptide transporter 2    TAP2
# Q08AF3                   LFN5_HUMAN Schlafen family member 5    LFN5
# Q13045               FLII_HUMAN Protein flightless-1 homolog    FLII
# Q63HN8        RN213_HUMAN E3 ubiquitin-protein ligase RNF213   RN213
# Q7Z5R6      AB1IP_HUMAN Amyloid beta A4 precursor protein-...  AB1IP
# Q8N8A2      ANR44_HUMAN Serine/threonine-protein phosphata...  ANR44
# Q9NUV9               GIMA4_HUMAN GTPase IMAP family member 4   GIMA4
# Q9P2E9                RRBP1_HUMAN Ribosome-binding protein 1   RRBP1
# O15260                    URF4_HUMAN Surfeit locus protein 4    URF4
# O60831                     PRAF2_HUMAN PRA1 family protein 2   PRAF2
# P04234      CD3D_HUMAN T-cell surface glycoprotein CD3 del...   CD3D
# P09564                          CD7_HUMAN T-cell antigen CD7     CD7
# P37235                HPCL1_HUMAN Hippocalcin-like protein 1   HPCL1
# Q15438                                CYH1_HUMAN Cytohesin-1    CYH1
# Q86WV1      KAP1_HUMAN Src kinase-associated phosphoprotei...   KAP1

# %% [markdown]
# ### Proteins higher or only in T cells by GeneID
# <code>T_cell_set</code> is defined here as both the above lists of names, those higher or only in T cells.

# %%
T_cell_set = list(higher_in_T_cells.GeneID)+list(T_cell_only_geneset.GeneID)

# %%
len(T_cell_set)
# Out:
# 182

# %% [markdown]
# ### KEGG pathway enrichment
# Here I do a functional pathway enrichment. I use GProfiler to run a KEGG analysis on the differential proteins.
# <code>B_cell_set</code> is proteins differentially expressed in B cells
# <code>T_cell_set</code> is proteins differentially expressed in T cells

# %%
gp = GProfiler(return_dataframe = True)

# %%
group1 = gp.profile(organism='hsapiens', query=list(B_cell_set))
group1[group1["source"] == "KEGG"]
# Out:
#     source      native                               name   p_value  \
# 27    KEGG  KEGG:04662  B cell receptor signaling pathway  0.000002
# 115   KEGG  KEGG:03410               Base excision repair  0.026099
#
#      significant                        description  term_size  query_size  \
# 27          True  B cell receptor signaling pathway         79          34
# 115         True               Base excision repair         33          34
#
#      intersection_size  effective_domain_size  precision    recall    query  \
# 27                   7                   8000   0.205882  0.088608  query_1
# 115                  3                   8000   0.088235  0.090909  query_1
#
#           parents
# 27   [KEGG:00000]
# 115  [KEGG:00000]

# %%
group2 = gp.profile(organism='hsapiens', query=list(T_cell_set))
group2[group2["source"] == "KEGG"]
# Out:
#     source      native                                  name   p_value  \
# 53    KEGG  KEGG:04640            Hematopoietic cell lineage  0.000073
# 62    KEGG  KEGG:05340              Primary immunodeficiency  0.000144
# 75    KEGG  KEGG:05135                    Yersinia infection  0.000814
# 87    KEGG  KEGG:04660     T cell receptor signaling pathway  0.001826
# 97    KEGG  KEGG:04530                        Tight junction  0.003333
# 129   KEGG  KEGG:04015                Rap1 signaling pathway  0.013098
# 161   KEGG  KEGG:05131                           Shigellosis  0.034457
# 162   KEGG  KEGG:04670  Leukocyte transendothelial migration  0.034803
# 164   KEGG  KEGG:05132                  Salmonella infection  0.037065
#
#      significant                           description  term_size  query_size  \
# 53          True            Hematopoietic cell lineage         95          46
# 62          True              Primary immunodeficiency         37          46
# 75          True                    Yersinia infection        136          46
# 87          True     T cell receptor signaling pathway        103          46
# 97          True                        Tight junction        169          46
# 129         True                Rap1 signaling pathway        210          46
# 161         True                           Shigellosis        246          46
# 162         True  Leukocyte transendothelial migration        114          46
# 164         True                  Salmonella infection        249          46
#
#      intersection_size  effective_domain_size  precision    recall    query  \
# 53                   7                   8000   0.152174  0.073684  query_1
# 62                   5                   8000   0.108696  0.135135  query_1
# 75                   7                   8000   0.152174  0.051471  query_1
# 87                   6                   8000   0.130435  0.058252  query_1
# 97                   7                   8000   0.152174  0.041420  query_1
# 129                  7                   8000   0.152174  0.033333  query_1
# 161                  7                   8000   0.152174  0.028455  query_1
# 162                  5                   8000   0.108696  0.043860  query_1
# 164                  7                   8000   0.152174  0.028112  query_1
#
#           parents
# 53   [KEGG:00000]
# 62   [KEGG:00000]
# 75   [KEGG:00000]
# 87   [KEGG:00000]
# 97   [KEGG:00000]
# 129  [KEGG:00000]
# 161  [KEGG:00000]
# 162  [KEGG:00000]
# 164  [KEGG:00000]

# %% [markdown]
# ## Suplementary Table: Distinguished Proteins
# Here we combine the data from the four categories in one dataframe and output it to a tab-separated file.

# %% [markdown]
# First, we get the names ofthe distinguished proteins.

# %%
distinguished_proteins = pd.concat([data_in_one_type[["GeneID"]],
                                   altered_proteins[["GeneID", "log2(B)-log2(T)", "pvalue"]]])

# %% [markdown]
# Next, we get the intensity data for these proteins.

# %%
altered_data = prot.data_frame.loc[altered.index]
one_type_data = data_in_one_type.drop(columns=["Type","Name","GeneID"], inplace=False)
altered_data = pd.concat([altered_data,one_type_data])

# %% [markdown]
# Next, we average by cell type, creating new columns in our <code>distinguished_proteins</code> dataframe.

# %%
samples=np.array(prot.data_raw.columns.values)

def mean_noNan(ser):
    ser = ser.dropna()
    if len(ser)==0:
        return np.nan
    return mean(ser)

for cell_type in cell_types:
    cells_of_type = list(s for i,s in enumerate(samples) if cell_type in s)
    type_data = altered_data[cells_of_type]
    means = type_data.apply(mean_noNan, axis=1)
    
    distinguished_proteins[("Mean {0}cells".format(cell_type))] = means

# %% [markdown]
# Here we check the column order and rearrange it as we like.

# %%
distinguished_proteins.columns
# Out:
# Index(['GeneID', 'log2(B)-log2(T)', 'pvalue',
#        'Mean Subject1_B_cells_062920cells',
#        'Mean Subject1_T_cells_062920cells'],
#       dtype='object')

# %%
distinguished_proteins = distinguished_proteins[["GeneID", "Mean {0}cells".format(cell_types[0]), 
                                                 "Mean {0}cells".format(cell_types[1]), "log2(B)-log2(T)", "pvalue"]]

# %% [markdown]
# Here we sort the proteins. This will sort them such that high abundance in B come first, down it low abundance in B, and finally sorting the T only proteins from low to high.

# %%
distinguished_proteins.sort_values(["Mean {0}cells".format(cell_types[0]),
                                    "Mean {0}cells".format(cell_types[1])],
                                   ascending=[False, False], inplace=True)

# %% [markdown]
# Finally, we have the finished dataframe.

# %%
distinguished_proteins
# Out:
#            GeneID  Mean Subject1_B_cells_062920cells  \
# Protein ID
# P04233       HG2A                       2.207058e+07
# P11836       CD20                       1.637971e+07
# P80723      BASP1                       1.047428e+07
# P01871       IGHM                       1.015840e+07
# P04839      CY24B                       9.617619e+06
# ...           ...                                ...
# Q15181       IPYR                      -1.855103e+00
# O00764       PDXK                      -1.913792e+00
# O00233      PSMD9                      -2.131818e+00
# Q96C19      EFHD2                      -2.467382e+00
# O14745      NHRF1                      -3.840696e+00
#
#             Mean Subject1_T_cells_062920cells  log2(B)-log2(T)    pvalue
# Protein ID
# P04233                               0.000000              NaN       NaN
# P11836                               0.000000              NaN       NaN
# P80723                               0.000000              NaN       NaN
# P01871                               0.000000              NaN       NaN
# P04839                               0.000000              NaN       NaN
# ...                                       ...              ...       ...
# Q15181                              -0.826866        -1.028237  0.000626
# O00764                              -1.189143        -0.724648  0.033635
# O00233                              -1.090425        -1.041393  0.042399
# Q96C19                               0.445918        -2.913300  0.016347
# O14745                               0.433786        -4.274482  0.000247
#
# [313 rows x 5 columns]

# %% [markdown]
# The last step is saving this dataframe to a file.

# %%
#distinguished_proteins.to_csv('data/distinguished_proteins_Sub1June_BvsT_FP_nMBR.tsv', sep='\t')
